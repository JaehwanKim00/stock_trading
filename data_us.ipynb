# %% [markdown]
# # 미국 주식 데이터 수집하기
#
# 퀀트 투자의 장점은 데이터만 있다면 동일한 투자 전략을 전세계 모든 국가에 적용할 수 있다는 점이다. 이번 장에서는 미국 전 종목의 티커 수집 및 주가, 재무제표, 가치지표를 다운로드 해보도록 하겠다.
#
# ## 티커 수집하기
#
# 우리나라는 거래소가 '한국거래소' 한 곳 뿐이지만, 미국은 매우 많은 거래소가 존재한다. 따라서 동일한 종목이 여러 거래소에서 거래되는 일도 발생한다. 그 중에서도 가장 규모가 큰 거래소는 뉴욕거래소(NYSE), 나스닥(NASDAQ), 아멕스(AMEX)이며, 해당 거래소에 상장된 종목들은 나스닥 홈페이지에서 제공된다.
#
# ```
# https://www.nasdaq.com/market-activity/stocks/screener
# ```
#
# 위 사이트에 접속하여 개발자 도구 화면을 연 후 하단의 [Download CSV] 버튼을 누르면, 해당 데이터를 받아오는 웹주소가 표시된다.
#
# ```{figure} image/data_us/us_ticker.png
# ---
# name: us_ticker
# ---
# 미국의 상장종목 리스트
# ```
#
# ```
# https://api.nasdaq.com/api/screener/stocks?tableonly=true&limit=25&offset=0&download=true
# ```
#
# 해당 주소에 접속하면, 각 종목에 대한 정보가 JSON 형태로 제공된다. 이를 크롤링 해보도록 하겠다.

# %%
import pandas as pd
import requests as rq

url = 'https://api.nasdaq.com/api/screener/stocks?tableonly=true&limit=25&offset=0&download=true'
headers = {
    "User-Agent":
    "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"
}

data = rq.get(url, headers=headers)
data_json = data.json()['data']
us_ticker = pd.DataFrame(data_json['rows'])

us_ticker.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
#       4 url = 'https://api.nasdaq.com/api/screener/stocks?tableonly=true&limit=25&offset=0&download=true'
#       5 headers = {
#       6     "User-Agent":
#       7     "Mozilla/5.0 (X11; CrOS x86_64 12871.102.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.141 Safari/537.36"
#       8 }
# ---> 10 data = rq.get(url, headers=headers)
#      11 data_json = data.json()['data']
#      12 us_ticker = pd.DataFrame(data_json['rows'])
#
# File c:\Users\kjh\anaconda3\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\kjh\anaconda3\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\kjh\anaconda3\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File c:\Users\kjh\anaconda3\lib\site-packages\urllib3\connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\urllib3\connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File c:\Users\kjh\anaconda3\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File c:\Users\kjh\anaconda3\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File c:\Users\kjh\anaconda3\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File c:\Users\kjh\anaconda3\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\Users\kjh\anaconda3\lib\ssl.py:1275, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1271     if flags != 0:
#    1272         raise ValueError(
#    1273           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1274           self.__class__)
# -> 1275     return self.read(nbytes, buffer)
#    1276 else:
#    1277     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\kjh\anaconda3\lib\ssl.py:1133, in SSLSocket.read(self, len, buffer)
#    1131 try:
#    1132     if buffer is not None:
# -> 1133         return self._sslobj.read(len, buffer)
#    1134     else:
#    1135         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# 1. 먼저 url과 헤더정보를 입력하며, 헤더의 User-Agent에는 웹브라우저 구별을 입력해준다. 해당 사이트는 크롤러와 같이 정체가 불분명한 웹브라우저를 통한 접속이 막혀 있어, 마치 모질라 혹은 크롬을 통해 접속한 것 처럼 데이터를 요청한다. 다양한 웹브라우저 리스트는 다음 사이트에서 확인할 수 있다.
# http://www.useragentstring.com/pages/useragentstring.php
# 2. `get()` 함수를 통해 페이지의 데이터를 불러온다.
# 3. `json()` 함수를 통해 json 형태로 불러온 후, data 부분을 선택한다.
# 4. json 형태를 데이터프레임 형태로 변경한다.
#
# ## 티커 클렌징
#
# 먼저 위에서 받은 데이터에서 종목 수를 확인해보도록 하자.

# %%
len(us_ticker)
# Out:
# 7008

# %% [markdown]
# 종목수를 살펴보면 상당히 많은 종목이 존재한다. 그러나 미국의 경우 동일한 종목이 여러 거래소에 상장된 경우가 있으므로, 이를 먼저 제거해주도록 한다. symbol과 name열 중 중복되는 종목이 있으면 첫번쨰 데이터만을 남기도록 한다.

# %%
us_ticker = us_ticker.loc[~us_ticker.symbol.duplicated(keep='first'), :]
us_ticker = us_ticker.loc[~us_ticker.name.duplicated(keep='first'), :]

len(us_ticker)
# Out:
# 6999

# %% [markdown]
# 다음으로 위에서 받은 데이터 중 모든 종목이 투자에 적합한 종목이 아니므로 클렌징 처리를 해주도록 한다.

# %%
us_ticker['marketCap'] = pd.to_numeric(us_ticker['marketCap'])

# %% [markdown]
#  먼저 시가총액에 해당하는 열을 숫자 형태로 바꿔준다. 이제 어떠한 종목이 일반적인 종목이 아닌지 탐색해보도록 하자.

# %%
import numpy as np

display(us_ticker.loc[us_ticker['marketCap'] == 0].head(),
        us_ticker[np.isnan(us_ticker['marketCap'])].head(),
        us_ticker.loc[us_ticker['name'].str.contains('%')].head())
# Out:
#    symbol                                               name lastsale  \
# 3    AACT  Ares Acquisition Corporation II Class A Ordina...  $10.875
# 6     AAM  AA Mission Acquisition Corp. Class A Ordinary ...   $10.05
# 43   ACAB  Atlantic Coastal Acquisition Corp. II Class A ...   $11.55
# 44  ACABU         Atlantic Coastal Acquisition Corp. II Unit   $12.54
# 72    ACP  abrdn Income Credit Strategies Fund Common Shares    $6.44
#
#    netchange pctchange  volume  marketCap        country ipoyear  \
# 3     -0.005   -0.046%   55446        0.0                   2023
# 6       0.01     0.10%   65394        0.0                   2024
# 43      0.20    1.762%   17487        0.0  United States    2022
# 44      0.00     0.00%       5        0.0  United States    2022
# 72     -0.05    -0.77%  714776        0.0  United States    2011
#
#                industry   sector                            url
# 3          Blank Checks  Finance   /market-activity/stocks/aact
# 6                                   /market-activity/stocks/aam
# 43         Blank Checks  Finance   /market-activity/stocks/acab
# 44         Blank Checks  Finance  /market-activity/stocks/acabu
# 72  Investment Managers  Finance    /market-activity/stocks/acp
#    symbol                                               name  lastsale  \
# 30  ABR^D  Arbor Realty Trust 6.375% Series D Cumulative ...    $19.00
# 31  ABR^E  Arbor Realty Trust 6.25% Series E Cumulative R...  $19.4996
# 32  ABR^F  Arbor Realty Trust 6.25% Series F Fixed-to-Flo...    $20.52
# 73  ACP^A  abrdn Income Credit Strategies Fund 5.250% Ser...  $23.4732
# 75  ACR^C  ACRES Commercial Realty Corp. 8.625% Fixed-to-...    $24.89
#
#    netchange pctchange volume  marketCap        country ipoyear industry  \
# 30     -0.79   -3.992%  14644        NaN  United States
# 31   -0.0504   -0.258%   2561        NaN  United States
# 32     -0.17   -0.822%  20739        NaN  United States
# 73   -0.6669   -2.763%    421        NaN  United States
# 75      0.02     0.08%  15288        NaN  United States
#
#    sector                            url
# 30         /market-activity/stocks/abr^d
# 31         /market-activity/stocks/abr^e
# 32         /market-activity/stocks/abr^f
# 73         /market-activity/stocks/acp^a
# 75         /market-activity/stocks/acr^c
#    symbol                                               name  lastsale  \
# 22  ABLLL  Abacus Life Inc. 9.875% Fixed Rate Senior Note...    $26.40
# 30  ABR^D  Arbor Realty Trust 6.375% Series D Cumulative ...    $19.00
# 31  ABR^E  Arbor Realty Trust 6.25% Series E Cumulative R...  $19.4996
# 32  ABR^F  Arbor Realty Trust 6.25% Series F Fixed-to-Flo...    $20.52
# 53  ACGLN  Arch Capital Group Ltd. Depositary Shares each...   $20.255
#
#    netchange pctchange volume     marketCap        country ipoyear  \
# 22      0.00     0.00%    227  1.970796e+09  United States
# 30     -0.79   -3.992%  14644           NaN  United States
# 31   -0.0504   -0.258%   2561           NaN  United States
# 32     -0.17   -0.822%  20739           NaN  United States
# 53    -0.005   -0.025%  60938  7.617052e+09        Bermuda
#
#                       industry   sector                            url
# 22         Investment Managers  Finance  /market-activity/stocks/ablll
# 30                                       /market-activity/stocks/abr^d
# 31                                       /market-activity/stocks/abr^e
# 32                                       /market-activity/stocks/abr^f
# 53  Property-Casualty Insurers  Finance  /market-activity/stocks/acgln

# %% [markdown]
# 첫째, 시가총액이 0인 종목, 시가총액이 NaN인 종목, 종목 이름에 '%'가 들어간 종목을 살펴보면 Acquisition 혹은 Warrant 등이거나 전환사채, 우선주 등 보통주가 아니다. 따라서 제외하는 것이 좋다.

# %%
us_ticker.loc[us_ticker['name'].str.contains('ETF | Fund')].head()
# Out:
#     symbol                                               name  lastsale  \
# 72     ACP  abrdn Income Credit Strategies Fund Common Shares     $6.44
# 73   ACP^A  abrdn Income Credit Strategies Fund 5.250% Ser...  $23.4732
# 84     ACV  Virtus Diversified Income & Convertible Fund C...   $20.645
# 115    ADX                 Adams Diversified Equity Fund Inc.    $21.73
# 120    AEF  abrdn Emerging Markets Equity Income Fund Inc....     $5.36
#
#     netchange pctchange  volume    marketCap        country ipoyear  \
# 72      -0.05    -0.77%  714776          0.0  United States    2011
# 73    -0.6669   -2.763%     421          NaN  United States
# 84      0.015    0.073%   41507  213943185.0  United States    2015
# 115      0.07    0.323%  223890          0.0  United States
# 120     -0.03   -0.557%   36797  575463000.0  United States
#
#                        industry   sector                            url
# 72          Investment Managers  Finance    /market-activity/stocks/acp
# 73                                        /market-activity/stocks/acp^a
# 84   Finance/Investors Services  Finance    /market-activity/stocks/acv
# 115         Investment Managers  Finance    /market-activity/stocks/adx
# 120  Finance/Investors Services  Finance    /market-activity/stocks/aef

# %% [markdown]
# 둘째, 종목명에 'ETF' 혹은 'Fund'가 들어간 종목은 펀드에 해당하므로 제외한다.

# %%
us_ticker.loc[us_ticker['name'].str.contains(
    'Depositary | each representing')].head()
# Out:
#    symbol                                               name lastsale  \
# 2    AACG   ATA Creativity Global American Depositary Shares    $1.01
# 19   ABEV  Ambev S.A. American Depositary Shares (Each re...    $2.15
# 40   ABVX               Abivax SA American Depositary Shares   $10.27
# 53  ACGLN  Arch Capital Group Ltd. Depositary Shares each...  $20.255
# 54  ACGLO  Arch Capital Group Ltd. Depositary Shares Each...   $23.40
#
#    netchange pctchange    volume     marketCap  country ipoyear  \
# 2     0.0776    8.323%    218765  3.232013e+07    China    2008
# 19     -0.03   -1.376%  19143857  3.387074e+10   Brazil    2013
# 40     -0.05   -0.484%    259218  6.461625e+08   France    2023
# 53    -0.005   -0.025%     60938  7.617052e+09  Bermuda
# 54     -0.04   -0.171%     25400  8.799753e+09  Bermuda
#
#                                       industry            sector  \
# 2                      Other Consumer Services       Real Estate
# 19         Beverages (Production/Distribution)  Consumer Staples
# 40  Biotechnology: Pharmaceutical Preparations       Health Care
# 53                  Property-Casualty Insurers           Finance
# 54                  Property-Casualty Insurers           Finance
#
#                               url
# 2    /market-activity/stocks/aacg
# 19   /market-activity/stocks/abev
# 40   /market-activity/stocks/abvx
# 53  /market-activity/stocks/acgln
# 54  /market-activity/stocks/acglo

# %% [markdown]
# 마지막으로 종목명에 'Depositary'나 'each representing'가 들어간 종목은 ADR 이므로 제외한다.

# %%
us_ticker = us_ticker.loc[~(us_ticker['marketCap'] == 0)]
us_ticker = us_ticker.loc[~(np.isnan(us_ticker['marketCap']))]
us_ticker = us_ticker.loc[~(us_ticker['name'].str.contains('%'))]
us_ticker = us_ticker.loc[~us_ticker['name'].str.contains('ETF | Fund')]
us_ticker = us_ticker.loc[~us_ticker['name'].str.contains('Depositary')]
us_ticker = us_ticker.loc[~us_ticker['name'].str.contains('each representing')]

len(us_ticker)
# Out:
# 5417

# %% [markdown]
# 이전에 비해 종목수가 현격하게 줄어들었다. 물론 해당 과정을 거쳐도 다중 클래스가 상장되어 있는 등 클렌징 처리를 할 종목이 많지만 그 수가 매우 적으므로, 효율성 측면에서 위의 과정 정도만으로도 충분하다. 이 중 필요한 열 선택 및 기준일(오늘 날짜)을 입력해준다.

# %%
from datetime import date, timedelta

date.today()

us_ticker = us_ticker[[
    'symbol', 'name', 'marketCap', 'country', 'ipoyear', 'industry', 'sector'
]]
us_ticker['date'] = date.today().strftime("%Y%m%d")
us_ticker['date'] = pd.to_datetime(us_ticker['date'])
us_ticker = us_ticker.replace({np.nan: None})

us_ticker.head(10)
# Out:
#    symbol                                        name     marketCap  \
# 0       A      Agilent Technologies Inc. Common Stock  3.932654e+10
# 1      AA             Alcoa Corporation Common Stock   1.048086e+10
# 4    AADI           Aadi Bioscience Inc. Common Stock  4.898352e+07
# 5     AAL   American Airlines Group Inc. Common Stock  8.897554e+09
# 7    AAME  Atlantic American Corporation Common Stock  3.325161e+07
# 8    AAOI   Applied Optoelectronics Inc. Common Stock  6.886838e+08
# 9    AAON                      AAON Inc. Common Stock  9.192562e+09
# 10    AAP                     Advance Auto Parts Inc.  2.163193e+09
# 11   AAPL                     Apple Inc. Common Stock  3.389154e+12
# 12    AAT     American Assets Trust Inc. Common Stock  1.622418e+09
#
#           country ipoyear                                          industry  \
# 0   United States    1999  Biotechnology: Laboratory Analytical Instruments
# 1   United States    2016                                          Aluminum
# 4   United States                Biotechnology: Pharmaceutical Preparations
# 5   United States                             Air Freight/Delivery Services
# 7   United States                                            Life Insurance
# 8   United States    2013                                    Semiconductors
# 9   United States                           Industrial Machinery/Components
# 10  United States                                 Auto & Home Supply Stores
# 11  United States    1980                            Computer Manufacturing
# 12  United States    2011                     Real Estate Investment Trusts
#
#                     sector       date
# 0              Industrials 2024-11-03
# 1              Industrials 2024-11-03
# 4              Health Care 2024-11-03
# 5   Consumer Discretionary 2024-11-03
# 7                  Finance 2024-11-03
# 8               Technology 2024-11-03
# 9              Industrials 2024-11-03
# 10  Consumer Discretionary 2024-11-03
# 11              Technology 2024-11-03
# 12             Real Estate 2024-11-03

# %% [markdown]
# 이제 위의 데이터를 DB에 저장한다. 먼저 SQL에서 다음의 쿼리를 통해 테이블(us_ticker)을 만든다.

# %%
use stock_db;

create table us_ticker
(
    symbol varchar(20) not null,
    name varchar(300),
    marketCap float,
    country varchar(20),
    ipoyear varchar(4),
    industry varchar(100),
    sector varchar(30),
    date date,
    primary key(symbol, date)
);

# %% [markdown]
# 마지막으로 티커 데이터를 해당 테이블에 저장한다.

# %%
import pymysql

con = pymysql.connect(user='root',
                      passwd='1346',
                      host='127.0.0.1',
                      db='stock_db',
                      charset='utf8')

mycursor = con.cursor()
query = """
    insert into us_ticker2 (symbol, name, marketCap, country, ipoyear, industry, sector, date)
    values (%s,%s,%s,%s,%s,%s,%s,%s) as new
    on duplicate key update
    name=new.name,marketCap=new.marketCap,country=new.country,
    ipoyear=new.ipoyear,industry=new.industry,sector=new.sector;    
"""

args = us_ticker.values.tolist()

mycursor.executemany(query, args)
con.commit()

con.close()

# %% [markdown]
# ## 주가 다운로드
#
# 미국 뿐만 아니라 전 세계 주가(한국 포함)의 경우 야후 파이낸스에서 제공하고 있다.
#
# ```
# https://finance.yahoo.com/
# ```
#
# 사이트에서 종목 티커를 검색한 후 [Historical Data] 탭을 선택하면 확인 및 다운로드가 가능하다. 또한 pandas_datareader 패키지의 `DataReader()` 함수를 사용하면 야후 API를 통해 주가 데이터를 매우 손쉽게 다운로드 받을 수도 있다. 예시로써 애플(AAPL)의 주가를 다운로드 받아보도록 하자.
#
# ```{figure} image/data_us/yahoo_price.png
# ---
# name: yahoo_price
# ---
# 야후에서 제공하는 주가 데이터
# ```

# %%
import yfinance as yf

price = yf.download('AAPL',progress=False,start='2000-01-01')
price.head()
# Out:
# Price                     Adj Close     Close      High       Low      Open  \
# Ticker                         AAPL      AAPL      AAPL      AAPL      AAPL
# Date
# 2000-01-03 00:00:00+00:00  0.844004  0.999442  1.004464  0.907924  0.936384
# 2000-01-04 00:00:00+00:00  0.772846  0.915179  0.987723  0.903460  0.966518
# 2000-01-05 00:00:00+00:00  0.784155  0.928571  0.987165  0.919643  0.926339
# 2000-01-06 00:00:00+00:00  0.716295  0.848214  0.955357  0.848214  0.947545
# 2000-01-07 00:00:00+00:00  0.750226  0.888393  0.901786  0.852679  0.861607
#
# Price                         Volume
# Ticker                          AAPL
# Date
# 2000-01-03 00:00:00+00:00  535796800
# 2000-01-04 00:00:00+00:00  512377600
# 2000-01-05 00:00:00+00:00  778321600
# 2000-01-06 00:00:00+00:00  767972800
# 2000-01-07 00:00:00+00:00  460734400

# %% [markdown]
# `DataReader()` 함수 내에 티커와 출처에 해당하는 'yahoo'를 입력하면 주가 정보를 매우 손쉽게 받을 수 있다.
#
# ```{note}
# 국내 주가 역시 야후 파이낸스를 통해 다운로드 받을 수 있다. 그러나 일부 중소형주의 경우 데이터가 존재하지 않는 문제가 있어 국내 사이트를 이용해 수집하는 것을 권장한다.
# ```
#
# ### 전 종목 주가 다운로드
#
# 미국 데이터 역시 국내 전종목 주가를 다운로드 받고 DB에 저장했던것과 동일하게 `for loop` 구문을 이용하면 된다. 먼저 SQL에서 미국 주가 데이터에 해당하는 테이블(us_price)를 만든다.

# %%
use stock_db;

create table us_price
(
    Date date,
    High double,
    Low double,
    Open double,
    Close double,
    Volume double,
    Adj_Close double,
    ticker varchar(20),
    primary key(Date, ticker)
);

# %% [markdown]
# 파이썬에서 아래 코드를 실행하면 for loop 구문을 통해 전종목 주가가 DB에 저장된다.

# %%
# 패키지 불러오기

import pymysql
import pandas as pd
import yfinance as yf
from datetime import date
import time
from tqdm import tqdm

# DB 연결
con = pymysql.connect(user='root',
                      passwd='1346',
                      host='127.0.0.1',
                      db='stock_db',
                      charset='utf8')

mycursor = con.cursor()

# 티커리스트 불러오기
ticker_list = pd.read_sql("""
select * from us_ticker2
where date = (select max(date) from us_ticker2);
""",
                          con=con)

# DB 저장 쿼리
query = """
    insert into us_price (Date, High, Low, Open, Close, Volume, Adj_Close, ticker)
    values (%s, %s,%s,%s,%s,%s,%s,%s) as new
    on duplicate key update
    High = new.High, Open = new.Open, Close = new.Close,
    Volume = new.Volume, Adj_Close = new.Adj_Close;
"""

# 오류 발생시 저장할 데이터프레임 생성
error_list = []
price_empty = pd.DataFrame({
    'Date': date.today().strftime("%Y-%m-%d"),
    'High': [None],
    'Low': [None],
    'Open': [None],
    'Close': [None],
    'Volumne': [None],
    'Adj_Close': [None]
})

# 전종목 주가 다운로드 및 저장
for i in tqdm(range(0, len(ticker_list))):

    # 빈 데이터프레임 복사
    price = price_empty.copy()

    # 티커 선택
    ticker = ticker_list['symbol'][i]

    # 오류 발생 시 이를 무시하고 다음 루프로 진행
    try:

        # url 생성
        price = yf.download(ticker,progress=False)

        # 데이터 클렌징
        price = price.reset_index()
        price['ticker'] = ticker
        price.rename(columns={'Adj Close': 'Adj_Close'}, inplace=True)

    except:

        # 오류 발생시 빈 데이터프레임을 불러온 후 다음 루프로 이동
        price['ticker'] = ticker
        error_list.append(ticker)

    # 주가 데이터를 DB에 저장
    args = price.values.tolist()

    mycursor.executemany(query, args)
    con.commit()

    # 타임슬립 적용
    time.sleep(2)

# DB 연결 종료
con.close()
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_13404\103438454.py:20: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ticker_list = pd.read_sql("""
#   0%|          | 18/5417 [01:27<6:06:13,  4.07s/it]
# 1 Failed download:
# ['ABLLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   0%|          | 20/5417 [01:32<4:51:42,  3.24s/it]
# 1 Failed download:
# ['ABLVW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   1%|          | 31/5417 [02:13<5:13:14,  3.49s/it]
# 1 Failed download:
# ['ABVEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   1%|          | 57/5417 [03:54<6:30:51,  4.38s/it]
# 1 Failed download:
# ['ACONW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   1%|▏         | 80/5417 [05:26<5:39:26,  3.82s/it]
# 1 Failed download:
# ['ADNWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   2%|▏         | 84/5417 [05:42<5:37:42,  3.80s/it]
# 1 Failed download:
# ['ADSEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   2%|▏         | 92/5417 [06:13<5:23:18,  3.64s/it]
# 1 Failed download:
# ['ADVWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   2%|▏         | 103/5417 [07:05<6:24:26,  4.34s/it]
# 1 Failed download:
# ['AENTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   2%|▏         | 119/5417 [08:11<5:51:28,  3.98s/it]
# 1 Failed download:
# ['AFRIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   3%|▎         | 151/5417 [10:11<5:34:24,  3.81s/it]
# 1 Failed download:
# ['AILEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   3%|▎         | 154/5417 [10:21<5:08:35,  3.52s/it]
# 1 Failed download:
# ['AIMDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   3%|▎         | 163/5417 [10:57<5:15:02,  3.60s/it]
# 1 Failed download:
# ['AIRJW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   3%|▎         | 167/5417 [11:11<5:23:08,  3.69s/it]
# 1 Failed download:
# ['AISPW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   4%|▍         | 228/5417 [15:15<5:11:28,  3.60s/it]
# 1 Failed download:
# ['ALVOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   5%|▌         | 285/5417 [19:03<5:27:38,  3.83s/it]
# 1 Failed download:
# ['ANGHW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   6%|▌         | 307/5417 [20:42<7:01:28,  4.95s/it]
# 1 Failed download:
# ['APCXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   6%|▋         | 341/5417 [22:51<4:31:36,  3.21s/it]
# 1 Failed download:
# ['ARBEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   6%|▋         | 352/5417 [23:50<5:25:40,  3.86s/it]
# 1 Failed download:
# ['AREBW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   7%|▋         | 360/5417 [24:17<4:38:08,  3.30s/it]
# 1 Failed download:
# ['ARKOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   8%|▊         | 410/5417 [27:58<5:15:47,  3.78s/it]
# 1 Failed download:
# ['ASTLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   8%|▊         | 432/5417 [29:19<4:34:58,  3.31s/it]
# 1 Failed download:
# ['ATNFW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   8%|▊         | 460/5417 [31:15<4:19:23,  3.14s/it]
# 1 Failed download:
# ['AUROW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   9%|▊         | 463/5417 [31:23<3:51:35,  2.80s/it]
# 1 Failed download:
# ['AUUDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#   9%|▉         | 481/5417 [32:41<5:17:06,  3.85s/it]
# 1 Failed download:
# ['AVPTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  10%|▉         | 524/5417 [36:27<7:24:52,  5.46s/it]
# 1 Failed download:
# ['BAERW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  11%|█         | 573/5417 [40:05<6:46:46,  5.04s/it]
# 1 Failed download:
# ['BCGWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  11%|█         | 585/5417 [41:13<8:03:15,  6.00s/it]
# 1 Failed download:
# ['BCTXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  11%|█         | 591/5417 [41:55<9:17:50,  6.94s/it]
# 1 Failed download:
# ['BDMDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  11%|█         | 599/5417 [42:30<5:21:26,  4.00s/it]
# 1 Failed download:
# ['BEATW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  11%|█         | 606/5417 [43:05<6:53:26,  5.16s/it]
# 1 Failed download:
# ['BENFW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  11%|█▏        | 611/5417 [43:21<4:37:16,  3.46s/it]
# 1 Failed download:
# ['BETRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  11%|█▏        | 618/5417 [43:46<4:32:58,  3.41s/it]
# 1 Failed download:
# ['BFRGW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  11%|█▏        | 620/5417 [43:51<3:55:25,  2.94s/it]
# 1 Failed download:
# ['BFRIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  12%|█▏        | 645/5417 [45:39<4:22:03,  3.30s/it]
# 1 Failed download:
# ['BIAFW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  13%|█▎        | 683/5417 [48:21<4:20:06,  3.30s/it]
# 1 Failed download:
# ['BLDEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  13%|█▎        | 714/5417 [50:47<7:35:30,  5.81s/it]
# 1 Failed download:
# ['BNAIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  13%|█▎        | 724/5417 [51:18<4:12:55,  3.23s/it]
# 1 Failed download:
# ['BNZIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  14%|█▍        | 759/5417 [54:05<7:12:22,  5.57s/it]Failed to get ticker 'BRK/A' reason: Expecting value: line 1 column 1 (char 0)
#
# 1 Failed download:
# ['BRK/A']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
#  14%|█▍        | 763/5417 [54:24<5:52:36,  4.55s/it]
# 1 Failed download:
# ['BRLSW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  14%|█▍        | 768/5417 [54:50<6:56:46,  5.38s/it]
# 1 Failed download:
# ['BROGW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  14%|█▍        | 782/5417 [55:52<5:22:22,  4.17s/it]
# 1 Failed download:
# ['BSLKW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  15%|█▍        | 792/5417 [56:35<4:41:32,  3.65s/it]
# 1 Failed download:
# ['BTBDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  15%|█▍        | 797/5417 [56:51<4:13:27,  3.29s/it]
# 1 Failed download:
# ['BTCTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  15%|█▍        | 804/5417 [57:20<5:06:42,  3.99s/it]
# 1 Failed download:
# ['BTMWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  16%|█▌        | 844/5417 [59:53<4:13:28,  3.33s/it]
# 1 Failed download:
# ['BZFDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  17%|█▋        | 930/5417 [1:07:32<5:48:03,  4.65s/it]
# 1 Failed download:
# ['CDIOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  17%|█▋        | 938/5417 [1:08:07<5:05:59,  4.10s/it]
# 1 Failed download:
# ['CDROW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  17%|█▋        | 941/5417 [1:08:14<3:44:52,  3.01s/it]
# 1 Failed download:
# ['CDTTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  18%|█▊        | 955/5417 [1:09:12<4:42:05,  3.79s/it]
# 1 Failed download:
# ['CELUW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  18%|█▊        | 963/5417 [1:09:43<4:31:11,  3.65s/it]
# 1 Failed download:
# ['CEROW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  18%|█▊        | 985/5417 [1:11:21<4:16:11,  3.47s/it]
# 1 Failed download:
# ['CGBSW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  19%|█▉        | 1026/5417 [1:14:34<5:56:39,  4.87s/it]
# 1 Failed download:
# ['CIFRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  19%|█▉        | 1031/5417 [1:14:58<6:04:05,  4.98s/it]
# 1 Failed download:
# ['CINGW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  20%|█▉        | 1082/5417 [1:18:46<6:18:15,  5.24s/it]
# 1 Failed download:
# ['CMAXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  20%|██        | 1097/5417 [1:20:09<5:07:41,  4.27s/it]
# 1 Failed download:
# ['CMPOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  21%|██        | 1136/5417 [1:23:17<4:39:02,  3.91s/it]
# 1 Failed download:
# ['COCHW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  21%|██        | 1143/5417 [1:23:41<4:07:55,  3.48s/it]
# 1 Failed download:
# ['COEPW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  21%|██▏       | 1163/5417 [1:25:18<4:27:32,  3.77s/it]
# 1 Failed download:
# ['COOTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  22%|██▏       | 1168/5417 [1:25:42<5:00:37,  4.25s/it]
# 1 Failed download:
# ['CORZW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  22%|██▏       | 1169/5417 [1:25:45<4:19:50,  3.67s/it]
# 1 Failed download:
# ['CORZZ']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  22%|██▏       | 1195/5417 [1:27:54<5:34:57,  4.76s/it]
# 1 Failed download:
# ['CPTNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  22%|██▏       | 1209/5417 [1:28:40<4:10:14,  3.57s/it]
# 1 Failed download:
# ['CRESW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  22%|██▏       | 1213/5417 [1:28:53<3:49:01,  3.27s/it]
# 1 Failed download:
# ['CRGOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  23%|██▎       | 1225/5417 [1:29:44<4:33:14,  3.91s/it]
# 1 Failed download:
# ['CRMLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  23%|██▎       | 1251/5417 [1:31:53<6:13:31,  5.38s/it]
# 1 Failed download:
# ['CSLRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  24%|██▍       | 1296/5417 [1:35:23<4:38:54,  4.06s/it]
# 1 Failed download:
# ['CURIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  25%|██▍       | 1332/5417 [1:38:33<5:35:42,  4.93s/it]
# 1 Failed download:
# ['CXAIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  25%|██▌       | 1368/5417 [1:41:27<3:38:32,  3.24s/it]
# 1 Failed download:
# ['DAVEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  25%|██▌       | 1374/5417 [1:41:46<3:36:15,  3.21s/it]
# 1 Failed download:
# ['DBGIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  26%|██▌       | 1406/5417 [1:44:20<3:52:23,  3.48s/it]
# 1 Failed download:
# ['DFLIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  26%|██▌       | 1417/5417 [1:45:12<4:39:53,  4.20s/it]
# 1 Failed download:
# ['DHAIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  27%|██▋       | 1481/5417 [1:50:19<4:08:13,  3.78s/it]
# 1 Failed download:
# ['DRMAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  27%|██▋       | 1485/5417 [1:50:38<4:57:32,  4.54s/it]
# 1 Failed download:
# ['DRTSW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  28%|██▊       | 1496/5417 [1:51:26<4:38:53,  4.27s/it]
# 1 Failed download:
# ['DSYWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  28%|██▊       | 1506/5417 [1:52:03<3:58:49,  3.66s/it]
# 1 Failed download:
# ['DTSTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  29%|██▊       | 1550/5417 [1:55:46<4:05:54,  3.82s/it]
# 1 Failed download:
# ['ECXWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  29%|██▊       | 1553/5417 [1:56:02<5:06:28,  4.76s/it]
# 1 Failed download:
# ['EDBLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  30%|██▉       | 1616/5417 [2:01:04<5:13:55,  4.96s/it]
# 1 Failed download:
# ['ENGNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  31%|███       | 1676/5417 [2:05:58<5:24:43,  5.21s/it]
# 1 Failed download:
# ['ESGLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  31%|███▏      | 1703/5417 [2:07:59<3:48:23,  3.69s/it]
# 1 Failed download:
# ['EUDAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  32%|███▏      | 1716/5417 [2:08:48<4:07:42,  4.02s/it]
# 1 Failed download:
# ['EVLVW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  32%|███▏      | 1754/5417 [2:11:43<4:37:05,  4.54s/it]
# 1 Failed download:
# ['FAASW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  33%|███▎      | 1763/5417 [2:12:25<4:36:13,  4.54s/it]
# 1 Failed download:
# ['FATBW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  33%|███▎      | 1777/5417 [2:13:21<3:53:01,  3.84s/it]
# 1 Failed download:
# ['FBYDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  33%|███▎      | 1811/5417 [2:16:19<5:09:21,  5.15s/it]
# 1 Failed download:
# ['FFIEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  34%|███▍      | 1867/5417 [2:20:51<4:55:53,  5.00s/it]
# 1 Failed download:
# ['FMSTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  35%|███▍      | 1895/5417 [2:22:49<3:06:20,  3.17s/it]
# 1 Failed download:
# ['FOXXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  36%|███▌      | 1950/5417 [2:26:46<3:03:49,  3.18s/it]
# 1 Failed download:
# ['FUFUW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  37%|███▋      | 1997/5417 [2:30:35<3:51:50,  4.07s/it]
# 1 Failed download:
# ['GCMGW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  37%|███▋      | 2007/5417 [2:31:25<4:00:55,  4.24s/it]
# 1 Failed download:
# ['GDEVW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  38%|███▊      | 2034/5417 [2:33:18<3:14:28,  3.45s/it]
# 1 Failed download:
# ['GFAIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  38%|███▊      | 2042/5417 [2:33:57<4:36:02,  4.91s/it]
# 1 Failed download:
# ['GGROW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  38%|███▊      | 2062/5417 [2:35:42<4:42:08,  5.05s/it]
# 1 Failed download:
# ['GIPRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  39%|███▉      | 2112/5417 [2:38:59<2:55:10,  3.18s/it]
# 1 Failed download:
# ['GOEVW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  39%|███▉      | 2125/5417 [2:39:44<2:47:24,  3.05s/it]
# 1 Failed download:
# ['GOVXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  40%|███▉      | 2155/5417 [2:41:32<2:55:29,  3.23s/it]
# 1 Failed download:
# ['GRRRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  40%|████      | 2169/5417 [2:42:20<3:00:27,  3.33s/it]
# 1 Failed download:
# ['GSMGW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  42%|████▏     | 2281/5417 [2:49:41<3:01:56,  3.48s/it]
# 1 Failed download:
# ['HOFVW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  42%|████▏     | 2284/5417 [2:49:52<3:07:27,  3.59s/it]
# 1 Failed download:
# ['HOLOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  42%|████▏     | 2298/5417 [2:51:01<3:31:16,  4.06s/it]
# 1 Failed download:
# ['HOVRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  42%|████▏     | 2302/5417 [2:51:15<3:14:06,  3.74s/it]
# 1 Failed download:
# ['HPAIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  43%|████▎     | 2345/5417 [2:54:06<2:35:21,  3.03s/it]
# 1 Failed download:
# ['HTZWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  43%|████▎     | 2348/5417 [2:54:18<3:09:50,  3.71s/it]
# 1 Failed download:
# ['HUBCW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  43%|████▎     | 2349/5417 [2:54:21<2:48:04,  3.29s/it]
# 1 Failed download:
# ['HUBCZ']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  43%|████▎     | 2356/5417 [2:54:44<3:01:28,  3.56s/it]
# 1 Failed download:
# ['HUMAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  44%|████▍     | 2376/5417 [2:56:04<2:39:51,  3.15s/it]
# 1 Failed download:
# ['HYMCW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  44%|████▍     | 2379/5417 [2:56:12<2:21:01,  2.79s/it]
# 1 Failed download:
# ['HYZNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  45%|████▍     | 2412/5417 [2:58:14<2:33:10,  3.06s/it]
# 1 Failed download:
# ['ICUCW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  45%|████▌     | 2448/5417 [3:00:37<2:20:51,  2.85s/it]
# 1 Failed download:
# ['ILLRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  45%|████▌     | 2464/5417 [3:01:33<2:36:06,  3.17s/it]
# 1 Failed download:
# ['IMTXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  46%|████▋     | 2518/5417 [3:04:39<2:49:02,  3.50s/it]
# 1 Failed download:
# ['INVZW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  48%|████▊     | 2578/5417 [3:08:24<2:54:52,  3.70s/it]
# 1 Failed download:
# ['IVDAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  48%|████▊     | 2610/5417 [3:10:24<2:50:53,  3.65s/it]
# 1 Failed download:
# ['JFBRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  49%|████▊     | 2631/5417 [3:11:58<2:55:53,  3.79s/it]
# 1 Failed download:
# ['JSPRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  49%|████▉     | 2656/5417 [3:13:24<2:27:10,  3.20s/it]
# 1 Failed download:
# ['KDLYW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  49%|████▉     | 2681/5417 [3:15:10<2:36:15,  3.43s/it]
# 1 Failed download:
# ['KITTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  50%|████▉     | 2688/5417 [3:15:37<2:58:16,  3.92s/it]
# 1 Failed download:
# ['KLTOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  50%|█████     | 2715/5417 [3:17:24<3:03:11,  4.07s/it]
# 1 Failed download:
# ['KPLTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  51%|█████     | 2742/5417 [3:19:03<2:55:57,  3.95s/it]
# 1 Failed download:
# ['KTTAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  51%|█████     | 2750/5417 [3:19:27<2:14:17,  3.02s/it]
# 1 Failed download:
# ['KWESW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  51%|█████▏    | 2788/5417 [3:21:38<2:14:48,  3.08s/it]
# 1 Failed download:
# ['LCFYW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  52%|█████▏    | 2797/5417 [3:22:12<2:34:34,  3.54s/it]
# 1 Failed download:
# ['LDTCW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  52%|█████▏    | 2814/5417 [3:23:22<2:22:14,  3.28s/it]
# 1 Failed download:
# ['LEXXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  52%|█████▏    | 2817/5417 [3:23:32<2:17:30,  3.17s/it]
# 1 Failed download:
# ['LFLYW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  52%|█████▏    | 2827/5417 [3:24:04<2:02:31,  2.84s/it]
# 1 Failed download:
# ['LGHLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  53%|█████▎    | 2897/5417 [3:28:38<2:13:55,  3.19s/it]
# 1 Failed download:
# ['LOTWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  54%|█████▍    | 2923/5417 [3:30:13<2:35:09,  3.73s/it]
# 1 Failed download:
# ['LSEAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  54%|█████▍    | 2935/5417 [3:30:53<2:13:33,  3.23s/it]
# 1 Failed download:
# ['LTRYW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  54%|█████▍    | 2945/5417 [3:31:25<2:11:01,  3.18s/it]
# 1 Failed download:
# ['LUNRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  54%|█████▍    | 2951/5417 [3:31:45<2:04:18,  3.02s/it]
# 1 Failed download:
# ['LVROW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  55%|█████▌    | 2986/5417 [3:33:56<2:20:25,  3.47s/it]
# 1 Failed download:
# ['MAPSW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  56%|█████▌    | 3032/5417 [3:37:13<2:45:52,  4.17s/it]
# 1 Failed download:
# ['MDAIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  57%|█████▋    | 3108/5417 [3:42:03<2:34:44,  4.02s/it]
# 1 Failed download:
# ['MKDWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  58%|█████▊    | 3149/5417 [3:44:47<2:14:48,  3.57s/it]
# 1 Failed download:
# ['MNTSW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  58%|█████▊    | 3155/5417 [3:45:09<2:32:21,  4.04s/it]
# 1 Failed download:
# ['MOBXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  59%|█████▉    | 3191/5417 [3:47:26<2:15:41,  3.66s/it]
# 1 Failed download:
# ['MRNOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  59%|█████▉    | 3204/5417 [3:48:18<2:36:08,  4.23s/it]
# 1 Failed download:
# ['MSAIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  60%|█████▉    | 3227/5417 [3:49:56<2:11:11,  3.59s/it]
# 1 Failed download:
# ['MTEKW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  60%|██████    | 3255/5417 [3:52:00<2:14:40,  3.74s/it]
# 1 Failed download:
# ['MVSTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  61%|██████    | 3303/5417 [3:54:46<1:50:55,  3.15s/it]
# 1 Failed download:
# ['NCNCW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  61%|██████    | 3306/5417 [3:54:55<1:46:24,  3.02s/it]
# 1 Failed download:
# ['NCPLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  61%|██████▏   | 3323/5417 [3:56:04<2:34:23,  4.42s/it]
# 1 Failed download:
# ['NEOVW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  61%|██████▏   | 3328/5417 [3:56:19<1:49:21,  3.14s/it]
# 1 Failed download:
# ['NESRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  62%|██████▏   | 3356/5417 [3:58:07<2:09:56,  3.78s/it]
# 1 Failed download:
# ['NIOBW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  62%|██████▏   | 3360/5417 [3:58:19<1:46:05,  3.09s/it]
# 1 Failed download:
# ['NIVFW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  62%|██████▏   | 3362/5417 [3:58:24<1:40:53,  2.95s/it]
# 1 Failed download:
# ['NIXXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  62%|██████▏   | 3366/5417 [3:58:42<2:19:26,  4.08s/it]
# 1 Failed download:
# ['NKGNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  62%|██████▏   | 3378/5417 [3:59:24<1:46:29,  3.13s/it]
# 1 Failed download:
# ['NMHIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  62%|██████▏   | 3385/5417 [3:59:44<1:37:30,  2.88s/it]
# 1 Failed download:
# ['NNAVW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  63%|██████▎   | 3419/5417 [4:01:48<1:50:20,  3.31s/it]
# 1 Failed download:
# ['NRSNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  63%|██████▎   | 3422/5417 [4:02:00<2:04:45,  3.75s/it]
# 1 Failed download:
# ['NRXPW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  64%|██████▍   | 3470/5417 [4:05:18<2:18:12,  4.26s/it]
# 1 Failed download:
# ['NVNIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  64%|██████▍   | 3482/5417 [4:06:04<1:41:53,  3.16s/it]
# 1 Failed download:
# ['NVVEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  64%|██████▍   | 3493/5417 [4:06:50<2:01:16,  3.78s/it]
# 1 Failed download:
# ['NWTNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  65%|██████▍   | 3499/5417 [4:07:14<1:55:06,  3.60s/it]
# 1 Failed download:
# ['NXGLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  65%|██████▍   | 3501/5417 [4:07:19<1:36:12,  3.01s/it]
# 1 Failed download:
# ['NXLIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  65%|██████▍   | 3506/5417 [4:07:39<2:06:55,  3.99s/it]
# 1 Failed download:
# ['NXPLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  65%|██████▍   | 3520/5417 [4:08:27<1:59:01,  3.76s/it]
# 1 Failed download:
# ['OABIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  65%|██████▌   | 3533/5417 [4:09:07<1:41:03,  3.22s/it]
# 1 Failed download:
# ['OCEAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  65%|██████▌   | 3538/5417 [4:09:23<1:34:30,  3.02s/it]
# 1 Failed download:
# ['OCSAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  65%|██████▌   | 3548/5417 [4:10:01<2:12:37,  4.26s/it]
# 1 Failed download:
# ['ODVWZ']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  66%|██████▋   | 3598/5417 [4:13:20<1:33:22,  3.08s/it]
# 1 Failed download:
# ['ONFOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  66%|██████▋   | 3602/5417 [4:13:32<1:29:37,  2.96s/it]
# 1 Failed download:
# ['ONMDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  67%|██████▋   | 3624/5417 [4:14:41<1:33:07,  3.12s/it]
# 1 Failed download:
# ['OPTXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  67%|██████▋   | 3632/5417 [4:15:12<1:55:15,  3.87s/it]
# 1 Failed download:
# ['ORGNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  68%|██████▊   | 3669/5417 [4:17:27<1:33:07,  3.20s/it]
# 1 Failed download:
# ['OXBRW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  68%|██████▊   | 3700/5417 [4:19:21<1:50:46,  3.87s/it]
# 1 Failed download:
# ['PAVMZ']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  69%|██████▊   | 3717/5417 [4:20:23<2:00:04,  4.24s/it]
# 1 Failed download:
# ['PBMWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  69%|██████▉   | 3732/5417 [4:21:23<1:33:02,  3.31s/it]
# 1 Failed download:
# ['PCTTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  69%|██████▉   | 3764/5417 [4:23:32<1:45:59,  3.85s/it]
# 1 Failed download:
# ['PETWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  70%|███████   | 3804/5417 [4:26:11<1:43:12,  3.84s/it]
# 1 Failed download:
# ['PIIIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  70%|███████   | 3813/5417 [4:26:39<1:21:42,  3.06s/it]
# 1 Failed download:
# ['PITAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  72%|███████▏  | 3895/5417 [4:32:08<1:24:03,  3.31s/it]
# 1 Failed download:
# ['PRENW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  73%|███████▎  | 3974/5417 [4:36:46<1:23:47,  3.48s/it]
# 1 Failed download:
# ['PXSAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  74%|███████▍  | 4001/5417 [4:38:17<1:11:22,  3.02s/it]
# 1 Failed download:
# ['QSIAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  75%|███████▍  | 4038/5417 [4:40:43<1:23:54,  3.65s/it]
# 1 Failed download:
# ['RCKTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  75%|███████▍  | 4058/5417 [4:42:01<1:16:57,  3.40s/it]
# 1 Failed download:
# ['RDZNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  75%|███████▌  | 4071/5417 [4:42:44<1:17:59,  3.48s/it]
# 1 Failed download:
# ['RELIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  75%|███████▌  | 4081/5417 [4:43:20<1:17:35,  3.48s/it]
# 1 Failed download:
# ['REVBW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  76%|███████▌  | 4103/5417 [4:44:51<1:27:16,  3.99s/it]
# 1 Failed download:
# ['RGTIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  76%|███████▋  | 4136/5417 [4:46:56<1:20:25,  3.77s/it]
# 1 Failed download:
# ['RMCOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  77%|███████▋  | 4187/5417 [4:50:11<1:24:44,  4.13s/it]
# 1 Failed download:
# ['RUMBW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  77%|███████▋  | 4193/5417 [4:50:30<1:06:35,  3.26s/it]
# 1 Failed download:
# ['RVMDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  77%|███████▋  | 4197/5417 [4:50:42<1:04:29,  3.17s/it]
# 1 Failed download:
# ['RVPHW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  78%|███████▊  | 4200/5417 [4:50:52<1:05:42,  3.24s/it]
# 1 Failed download:
# ['RVSNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  78%|███████▊  | 4219/5417 [4:52:00<1:02:30,  3.13s/it]
# 1 Failed download:
# ['RZLVW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  78%|███████▊  | 4224/5417 [4:52:15<59:31,  2.99s/it]
# 1 Failed download:
# ['SABSW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  78%|███████▊  | 4234/5417 [4:52:49<1:04:31,  3.27s/it]
# 1 Failed download:
# ['SAIHW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  78%|███████▊  | 4248/5417 [4:53:41<1:06:53,  3.43s/it]
# 1 Failed download:
# ['SATLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  79%|███████▊  | 4257/5417 [4:54:13<1:20:42,  4.17s/it]
# 1 Failed download:
# ['SBCWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  79%|███████▊  | 4262/5417 [4:54:29<1:05:05,  3.38s/it]
# 1 Failed download:
# ['SBFMW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  79%|███████▉  | 4279/5417 [4:55:47<1:32:28,  4.88s/it]
# 1 Failed download:
# ['SCLXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  79%|███████▉  | 4293/5417 [4:56:35<59:45,  3.19s/it]
# 1 Failed download:
# ['SDAWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  80%|████████  | 4356/5417 [5:00:20<58:24,  3.30s/it]
# 1 Failed download:
# ['SHFSW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  81%|████████  | 4361/5417 [5:00:34<49:02,  2.79s/it]
# 1 Failed download:
# ['SHMDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  81%|████████  | 4366/5417 [5:00:50<55:14,  3.15s/it]
# 1 Failed download:
# ['SHOTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  81%|████████▏ | 4413/5417 [5:04:02<1:01:09,  3.65s/it]
# 1 Failed download:
# ['SLDPW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  82%|████████▏ | 4436/5417 [5:05:19<46:43,  2.86s/it]
# 1 Failed download:
# ['SLXNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  82%|████████▏ | 4459/5417 [5:06:45<47:44,  2.99s/it]
# 1 Failed download:
# ['SMXWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  82%|████████▏ | 4465/5417 [5:07:06<52:16,  3.29s/it]
# 1 Failed download:
# ['SNAXW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  83%|████████▎ | 4501/5417 [5:09:16<56:14,  3.68s/it]
# 1 Failed download:
# ['SONDW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  83%|████████▎ | 4510/5417 [5:09:46<53:54,  3.57s/it]
# 1 Failed download:
# ['SOUNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  84%|████████▍ | 4544/5417 [5:11:43<51:35,  3.55s/it]
# 1 Failed download:
# ['SQFTW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  84%|████████▍ | 4562/5417 [5:12:51<43:57,  3.09s/it]
# 1 Failed download:
# ['SRZNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  85%|████████▌ | 4614/5417 [5:16:08<44:18,  3.31s/it]
# 1 Failed download:
# ['STSSW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  85%|████████▌ | 4631/5417 [5:17:36<51:52,  3.96s/it]
# 1 Failed download:
# ['SURGW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  86%|████████▌ | 4637/5417 [5:17:53<38:01,  2.93s/it]
# 1 Failed download:
# ['SVMHW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  86%|████████▌ | 4639/5417 [5:17:58<36:03,  2.78s/it]
# 1 Failed download:
# ['SVREW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  86%|████████▌ | 4644/5417 [5:18:15<39:01,  3.03s/it]
# 1 Failed download:
# ['SWAGW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  86%|████████▌ | 4654/5417 [5:18:52<47:08,  3.71s/it]
# 1 Failed download:
# ['SWVLW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  86%|████████▌ | 4661/5417 [5:19:25<52:12,  4.14s/it]
# 1 Failed download:
# ['SXTPW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  86%|████████▋ | 4675/5417 [5:20:13<37:27,  3.03s/it]
# 1 Failed download:
# ['SYTAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  86%|████████▋ | 4682/5417 [5:20:45<49:12,  4.02s/it]
# 1 Failed download:
# ['TALKW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  87%|████████▋ | 4696/5417 [5:21:39<45:32,  3.79s/it]
# 1 Failed download:
# ['TBLAW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  87%|████████▋ | 4704/5417 [5:22:06<46:50,  3.94s/it]
# 1 Failed download:
# ['TCBPW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  89%|████████▊ | 4803/5417 [5:28:44<43:54,  4.29s/it]
# 1 Failed download:
# ['TMTCR']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  89%|████████▉ | 4814/5417 [5:29:22<32:25,  3.23s/it]
# 1 Failed download:
# ['TNONW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  89%|████████▉ | 4818/5417 [5:29:32<28:31,  2.86s/it]
# 1 Failed download:
# ['TOIIW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  91%|█████████ | 4909/5417 [5:35:43<32:21,  3.82s/it]
# 1 Failed download:
# ['TVGNW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  92%|█████████▏| 4965/5417 [5:39:35<32:14,  4.28s/it]
# 1 Failed download:
# ['UHGWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  92%|█████████▏| 4971/5417 [5:40:04<34:10,  4.60s/it]
# 1 Failed download:
# ['UKOMW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  93%|█████████▎| 5018/5417 [5:43:13<24:54,  3.75s/it]
# 1 Failed download:
# ['USGOW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  94%|█████████▎| 5074/5417 [5:46:45<17:04,  2.99s/it]
# 1 Failed download:
# ['VGASW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  95%|█████████▍| 5132/5417 [5:50:31<16:10,  3.41s/it]
# 1 Failed download:
# ['VRMEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  95%|█████████▌| 5148/5417 [5:51:29<17:37,  3.93s/it]
# 1 Failed download:
# ['VSEEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  95%|█████████▌| 5155/5417 [5:51:52<12:59,  2.97s/it]
# 1 Failed download:
# ['VSTEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  96%|█████████▋| 5226/5417 [5:56:52<13:49,  4.34s/it]
# 1 Failed download:
# ['WGSWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  97%|█████████▋| 5249/5417 [5:58:17<09:32,  3.41s/it]
# 1 Failed download:
# ['WLDSW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  98%|█████████▊| 5317/5417 [6:03:13<05:35,  3.36s/it]
# 1 Failed download:
# ['XBPEW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  98%|█████████▊| 5334/5417 [6:04:15<05:53,  4.25s/it]
# 1 Failed download:
# ['XOSWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  99%|█████████▉| 5373/5417 [6:06:22<02:03,  2.81s/it]
# 1 Failed download:
# ['ZAPPW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  99%|█████████▉| 5379/5417 [6:06:41<02:04,  3.27s/it]
# 1 Failed download:
# ['ZCARW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
#  99%|█████████▉| 5386/5417 [6:07:01<01:25,  2.76s/it]
# 1 Failed download:
# ['ZEOWW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# 100%|█████████▉| 5404/5417 [6:07:55<00:35,  2.70s/it]
# 1 Failed download:
# ['ZOOZW']: YFInvalidPeriodError("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# 100%|██████████| 5417/5417 [6:08:34<00:00,  4.08s/it]

# %%
error_list
# Out:
# []

# %% [markdown]
# 1. DB에 연결한다.
# 2. 기준일이 최대, 즉 최근일 기준 보통주에 해당하는 종목 리스트(ticker_list)만 불러온다.
# 3. DB에 저장할 쿼리(query)를 입력한다.
# 4. 페이지 오류, 통신 오류 등 오류가 발생할 경우 저장할 빈 데이터프레임(price_empty)을 생성한다.
# 5. `for loop` 구문을 통해 전종목 주가를 다운로드 받으며, 진행상황을 알기위해 `tqdm()` 함수를 이용한다.
# 6. `DataReader()` 함수를 통해 야후 파이낸스에서 주가를 받은 후 클렌징 처리한다.
# 7.  `try except` 문을 통해 오류가 발생시 위에서 생성한 빈 데이터프레임을 이용한다.
# 8. 주가 데이터를 DB에 저장한다.
# 9. 무한 크롤링을 방지하기 위해 한 번의 루프가 끝날 때마다 타임슬립을 적용한다.
# 10. 모든 작업이 끝나면 DB와의 연결을 종료한다.
#
# ```{figure} image/data_us/sql_price.png
# ---
# name: sql_price
# ---
# 미국 주가 테이블
# ```
#
# ## 재무제표 크롤링
#
# 재무제표 역시 야후 파이낸스에서 구할 수 있다. [Financials] 탭을 클릭하면 연간 및 분기 기준 재무제표를 제공하고 있다. 해당 데이터를 다운로드 받을 수 있는 여러 패키지가 존재하며, 본 책에서는 그 중에서도 `yahoo_fin` 패키지를 사용하도록 하겠다. 해당 패키지의 자세한 설명은 아래 사이트에서 확인할 수 있다.
#
# ```
# http://theautomatic.net/yahoo_fin-documentation/
# ```
#
# ```{figure} image/data_us/yahoo_fs.png
# ---
# name: yahoo_fs
# ---
# 야후에서 제공하는 재무제표 데이터
# ```
#
# 해당 패키지의 `get_financials()` 함수를 이용하면 손익계산서, 재무상태표, 현금흐름표를 한번에 다운로드 받을 수 있으며, 예시로 애플(AAPL) 종목의 연간 재무제표를 받아보도록 하겠다.

# %%
from yahooquery import Ticker

data = Ticker('AAPL')
data.asset_profile
data.summary_detail
data.history()
# Out:
# c:\Users\kjh\anaconda3\lib\site-packages\yahooquery\utils\__init__.py:1470: FutureWarning: 'S' is deprecated and will be removed in a future version. Please use 's' instead of 'S'.
#   has_live_indice = index_utc[-1] >= last_trade - pd.Timedelta(2, "S")
# c:\Users\kjh\anaconda3\lib\site-packages\yahooquery\ticker.py:1333: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["dividends"].fillna(0, inplace=True)
#                          open        high         low       close    volume  \
# symbol date
# AAPL   2024-01-02  187.149994  188.440002  183.889999  185.639999  82488700
#        2024-01-03  184.220001  185.880005  183.429993  184.250000  58414500
#        2024-01-04  182.149994  183.089996  180.880005  181.910004  71983600
#        2024-01-05  181.990005  182.759995  180.169998  181.179993  62303300
#        2024-01-08  182.089996  185.600006  181.500000  185.559998  59144500
# ...                       ...         ...         ...         ...       ...
#        2024-10-28  233.320007  234.729996  232.550003  233.399994  36087100
#        2024-10-29  233.100006  234.330002  232.320007  233.669998  35417200
#        2024-10-30  232.610001  233.470001  229.550003  230.100006  47070900
#        2024-10-31  229.339996  229.830002  225.369995  225.910004  64370100
#        2024-11-01  220.970001  225.350006  220.270004  222.910004  65242200
#
#                      adjclose  dividends
# symbol date
# AAPL   2024-01-02  184.938217        0.0
#        2024-01-03  183.553467        0.0
#        2024-01-04  181.222336        0.0
#        2024-01-05  180.495071        0.0
#        2024-01-08  184.858521        0.0
# ...                       ...        ...
#        2024-10-28  233.399994        0.0
#        2024-10-29  233.669998        0.0
#        2024-10-30  230.100006        0.0
#        2024-10-31  225.910004        0.0
#        2024-11-01  222.910004        0.0
#
# [212 rows x 7 columns]

# %%
data_y = data.all_financial_data(frequency='a')
data_y
# Out:
#          asOfDate periodType currencyCode  AccountsPayable  \
# symbol
# AAPL   2020-09-30        12M          USD     4.229600e+10
# AAPL   2021-09-30        12M          USD     5.476300e+10
# AAPL   2022-09-30        12M          USD     6.411500e+10
# AAPL   2023-09-30        12M          USD     6.261100e+10
#
#         AccountsReceivable  AccumulatedDepreciation  \
# symbol
# AAPL          1.612000e+10            -6.676000e+10
# AAPL          2.627800e+10            -7.028300e+10
# AAPL          2.818400e+10            -7.234000e+10
# AAPL          2.950800e+10            -7.088400e+10
#
#         AvailableForSaleSecurities  BasicAverageShares  BasicEPS  \
# symbol
# AAPL                  1.008870e+11        1.735212e+10      3.31
# AAPL                  1.278770e+11        1.670127e+10      5.67
# AAPL                  1.208050e+11        1.621596e+10      6.15
# AAPL                  1.005440e+11        1.574423e+10      6.16
#
#         BeginningCashPosition  ...  TotalExpenses  \
# symbol                         ...
# AAPL             5.022400e+10  ...   2.082270e+11
# AAPL             3.978900e+10  ...   2.568680e+11
# AAPL             3.592900e+10  ...   2.748910e+11
# AAPL             2.497700e+10  ...   2.689840e+11
#
#         TotalLiabilitiesNetMinorityInterest  TotalNonCurrentAssets  \
# symbol
# AAPL                           2.585490e+11           1.801750e+11
# AAPL                           2.879120e+11           2.161660e+11
# AAPL                           3.020830e+11           2.173500e+11
# AAPL                           2.904370e+11           2.090170e+11
#
#         TotalNonCurrentLiabilitiesNetMinorityInterest  \
# symbol
# AAPL                                     1.531570e+11
# AAPL                                     1.624310e+11
# AAPL                                     1.481010e+11
# AAPL                                     1.451290e+11
#
#         TotalOperatingIncomeAsReported  TotalRevenue  TotalTaxPayable  \
# symbol
# AAPL                      6.628800e+10  2.745150e+11              NaN
# AAPL                      1.089490e+11  3.658170e+11              NaN
# AAPL                      1.194370e+11  3.943280e+11     6.552000e+09
# AAPL                      1.143010e+11  3.832850e+11     8.819000e+09
#
#         TradeandOtherPayablesNonCurrent  TreasurySharesNumber  WorkingCapital
# symbol
# AAPL                       2.817000e+10                   NaN    3.832100e+10
# AAPL                       2.468900e+10                   NaN    9.355000e+09
# AAPL                       1.665700e+10                   NaN   -1.857700e+10
# AAPL                       1.545700e+10                   0.0   -1.742000e+09
#
# [4 rows x 168 columns]

# %%
import numpy as np

data_y.reset_index(inplace=True)
data_y = data_y.loc[:,~data_y.columns.isin(['periodType','currencyCode'])]
data_y = data_y.melt(id_vars = ['symbol','asOfDate'])
data_y = data_y.replace([np.nan],None)
data_y['freq'] = 'y'
data_y.columns = ['ticker','date','account','value','freq']
data_y
# Out:
#     ticker       date               account          value freq
# 0     AAPL 2020-09-30       AccountsPayable  42296000000.0    y
# 1     AAPL 2021-09-30       AccountsPayable  54763000000.0    y
# 2     AAPL 2022-09-30       AccountsPayable  64115000000.0    y
# 3     AAPL 2023-09-30       AccountsPayable  62611000000.0    y
# 4     AAPL 2020-09-30    AccountsReceivable  16120000000.0    y
# ..     ...        ...                   ...            ...  ...
# 655   AAPL 2023-09-30  TreasurySharesNumber            0.0    y
# 656   AAPL 2020-09-30        WorkingCapital  38321000000.0    y
# 657   AAPL 2021-09-30        WorkingCapital   9355000000.0    y
# 658   AAPL 2022-09-30        WorkingCapital -18577000000.0    y
# 659   AAPL 2023-09-30        WorkingCapital  -1742000000.0    y
#
# [660 rows x 5 columns]

# %%
import yahoo_fin.stock_info as si

data_y = si.get_financials('AAPL', yearly=True, quarterly=False)
data_y.keys()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 import yahoo_fin.stock_info as si
#       3 data_y = si.get_financials('AAPL', yearly=True, quarterly=False)
#       4 data_y.keys()
#
# ModuleNotFoundError: No module named 'yahoo_fin'

# %% [markdown]
# 인자에 `yearly = True, quarterly = False`는 연간 재무제표를 의미하며, 딕셔너리 형태로 세 종류의 재무제표가 다운로드 되었다. 이를 하나의 데이터프레임으로 바꿔주도록 한다.

# %%
import pandas as pd

data_fs_y = pd.concat([v for k, v in data_y.items()])
data_fs_y = data_fs_y.stack().reset_index()
data_fs_y.columns = ['account', 'date', 'value']
data_fs_y['freq'] = 'y'

data_fs_y.head()

# %% [markdown]
# 1. 딕셔너리의 value에 해당하는 부분만을 선택한 후 `concat()` 함수를 통해 데이터프레임 형태로 합쳐준다.
# 2. `stack()` 함수를 통해 데이터를 위에서 아래로 길게 재구조화 해주며, `reset_index()` 함수를 통해 인덱스를 초기화한다.
# 3. 열 이름을 변경한다.
# 4. freq 열에 연간에 해당하는 'y'를 입력한다.
#
# 이처럼 패키지를 이용하여 미국 데이터도 매우 쉽게 다운로드 받을 수 있다. 분기별 재무제표를 받는법도 위와 같으며, 인자만 `yearly=False, quarterly=True`로 변경하면 된다.

# %%
data_q = si.get_financials('AAPL', yearly=False, quarterly=True)
data_fs_q = pd.concat([v for k, v in data_q.items()])
data_fs_q = data_fs_q.stack().reset_index()
data_fs_q.columns = ['account', 'date', 'value']
data_fs_q['freq'] = 'q'

data_fs_q.head()

# %% [markdown]
# ### 전 종목 재무제표 다운로드
#
# `for loop` 구문을 이용하여 전 종목 재무제표를 다운로드 받도록 하겠다. 먼저 SQL에서 미국 재무제표 데이터에 해당하는 테이블(us_fs)를 만든다.

# %%
use stock_db;

create table us_fs
(
    ticker varchar(20),
    date date,
    account varchar(100),
    value double,
    freq varchar(1),
        
    primary key(account, date, ticker, freq)
);

# %% [markdown]
# 이제 파이썬에서 아래 코드를 실행하면 for loop 구문을 통해 전 종목 재무제표가 DB에 저장된다.

# %%
# 패키지 불러오기
from sqlalchemy import create_engine
import pymysql
import pandas as pd
from yahooquery import Ticker
import numpy as np
import time
from tqdm import tqdm

# DB 연결
engine = create_engine('mysql+pymysql://root:1346@127.0.0.1:3306/stock_db')
con = pymysql.connect(
    user='root', passwd='1346', host='127.0.0.1', db='stock_db', charset='utf8'
)

mycursor = con.cursor()

# 티커리스트 불러오기
ticker_list = pd.read_sql("""
select * from us_ticker2
where date = (select max(date) from us_ticker2);
""", con = con)


# DB 저장 쿼리
query_fs = """
    insert into us_fs2 (ticker,date,account,value,freq)
    values (%s,%s,%s,%s,%s) as new
    on duplicate key update
    value = new.value;
"""


# 오류 발생시 저장할 데이터프레임 생성
error_list = []



# 전종목 주가 다운로드 및 저장

for i in tqdm(range(0, len(ticker_list))): 

    
    
    # 티커 선택
    ticker = ticker_list['symbol'][i]        
    
    # 오류 발생 시 이를 무시하고 다음 루프로 진행
    try:
        
       data = Ticker(ticker)

       # 재무제표 다운로드
       
       # 연간
       data_y = data.all_financial_data(frequency='a')
       data_y.reset_index(inplace=True)
       data_y = data_y.loc[:,~data_y.columns.isin(['periodType','currencyCode'])]
       data_y = data_y.melt(id_vars = ['symbol','asOfDate'])
       data_y = data_y.replace([np.nan],None)
       data_y['freq'] = 'y'
       data_y.columns = ['ticker','date','account','value','freq']

       # 분기
       data_q = data.all_financial_data(frequency='q')
       data_q.reset_index(inplace=True)
       data_q = data_q.loc[:,~data_q.columns.isin(['periodType','currencyCode'])]
       data_q = data_q.melt(id_vars = ['symbol','asOfDate'])
       data_q = data_q.replace([np.nan],None)
       data_q['freq'] = 'q'
       data_q.columns = ['ticker','date','account','value','freq']
       
       # 합치기
       data_fs = pd.concat([data_y, data_q], axis = 0)
                   

       # 주가 데이터를 DB에 저장
       args  = data_fs.values.tolist() 
       mycursor.executemany(query_fs, args)
       con.commit()

    except:
        
        # 오류 발생시 빈 데이터프레임을 불러온 후 다음 루프로 이동
        print(ticker)
        error_list.append(ticker)   
       
    

    
    # 타임슬립 적용
    time.sleep(2)    
    
# DB 연결 종료
engine.dispose()
con.close()
# Out:
# c:\Users\kjh\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# c:\Users\kjh\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_15544\65994516.py:18: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ticker_list = pd.read_sql("""
#   0%|          | 9/5417 [01:07<11:25:44,  7.61s/it]
# AAT
#   1%|          | 32/5417 [03:42<10:03:38,  6.73s/it]
# AC
#   1%|          | 33/5417 [03:48<9:28:43,  6.34s/it]
# ACA
#   1%|          | 34/5417 [04:00<10:34:25,  7.07s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 91
#      85         error_list.append(ticker)
#      90     # 타임슬립 적용
# ---> 91     time.sleep(2)
#      93 # DB 연결 종료
#      95 con.close()
#
# KeyboardInterrupt:

# %%
con.close()

# %% [markdown]
# 1. DB에 연결한다.
# 2. 기준일이 최대, 즉 최근일 기준 보통주에 해당하는 종목 리스트(ticker_list)만 불러온다.
# 3. DB에 저장할 쿼리(query)를 입력한다.
# 4. 페이지 오류, 통신 오류 등 오류가 발생할 경우 저장할 빈 데이터프레임(fs_empty)을 생성한다.
# 5. `for loop` 구문을 통해 전종목 재무제표를 다운로드 받으며, 진행상황을 알기위해 `tqdm()` 함수를 이용한다.
# 6. `get_financials()` 함수를 이용해 연간 및 분기 재무제표를 받은 후, 두 테이블을 `concat()` 함수를 통해 행으로 묶어준다.
# 7. 재무제표 데이터를 DB에 저장한다.
# 8. 무한 크롤링을 방지하기 위해 한 번의 루프가 끝날 때마다 타임슬립을 적용한다.
# 9. 모든 작업이 끝나면 DB와의 연결을 종료한다.
#
# ```{figure} image/data_us/sql_fs.png
# ---
# name: sql_fs
# ---
# 미국 재무제표 테이블
# ```
#
# ```{note}
# 미국 종목들의 가치지표는 국내 재무제표 데이터를 이용해 가치지표를 계산했던 것과 동일한 방법으로 계산할 수 있으므로, 이는 생략하도록 한다.
# ```

# %%
ticker
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 ticker
#
# NameError: name 'ticker' is not defined

# %%
# 티커리스트 불러오기
ticker_list = pd.read_sql("""
select * from us_ticker2
where date = (select max(date) from us_ticker2);
""", con = con)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_15544\3426029971.py:2: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   ticker_list = pd.read_sql("""

# %%
ticker_list
# Out:
#      symbol                                               name     marketCap  \
# 0         A             Agilent Technologies Inc. Common Stock  3.932650e+10
# 1        AA                    Alcoa Corporation Common Stock   1.048090e+10
# 2      AADI                  Aadi Bioscience Inc. Common Stock  4.898350e+07
# 3       AAL          American Airlines Group Inc. Common Stock  8.897550e+09
# 4      AAME         Atlantic American Corporation Common Stock  3.325160e+07
# ...     ...                                                ...           ...
# 5412   ZVRA               Zevra Therapeutics Inc. Common Stock  4.419890e+08
# 5413   ZVSA             ZyVersa Therapeutics Inc. Common Stock  1.965760e+06
# 5414    ZWS  Zurn Elkay Water Solutions Corporation Common ...  6.292990e+09
# 5415   ZYME                        Zymeworks Inc. Common Stock  9.435090e+08
# 5416   ZYXI                            Zynex Inc. Common Stock  2.789670e+08
#
#             country ipoyear  \
# 0     United States    1999
# 1     United States    2016
# 2     United States
# 3     United States
# 4     United States
# ...             ...     ...
# 5412  United States
# 5413  United States    2022
# 5414  United States    2012
# 5415  United States
# 5416  United States
#
#                                                industry  \
# 0      Biotechnology: Laboratory Analytical Instruments
# 1                                              Aluminum
# 2            Biotechnology: Pharmaceutical Preparations
# 3                         Air Freight/Delivery Services
# 4                                        Life Insurance
# ...                                                 ...
# 5412         Biotechnology: Pharmaceutical Preparations
# 5413         Biotechnology: Pharmaceutical Preparations
# 5414                    Industrial Machinery/Components
# 5415         Biotechnology: Pharmaceutical Preparations
# 5416  Biotechnology: Electromedical & Electrotherape...
#
#                       sector        date
# 0                Industrials  2024-11-03
# 1                Industrials  2024-11-03
# 2                Health Care  2024-11-03
# 3     Consumer Discretionary  2024-11-03
# 4                    Finance  2024-11-03
# ...                      ...         ...
# 5412             Health Care  2024-11-03
# 5413             Health Care  2024-11-03
# 5414             Industrials  2024-11-03
# 5415             Health Care  2024-11-03
# 5416             Health Care  2024-11-03
#
# [5417 rows x 8 columns]

# %%
ticker = ticker_list['symbol']
ticker
# Out:
# 0          A
# 1         AA
# 2       AADI
# 3        AAL
# 4       AAME
#         ...
# 5412    ZVRA
# 5413    ZVSA
# 5414     ZWS
# 5415    ZYME
# 5416    ZYXI
# Name: symbol, Length: 5417, dtype: object

# %%
# 티커 데이터를 리스트로 변환
ticker_list = ticker.tolist()
print(ticker_list)
# Out:
# ['A', 'AA', 'AADI', 'AAL', 'AAME', 'AAOI', 'AAON', 'AAP', 'AAPL', 'AAT', 'AB', 'ABAT', 'ABBV', 'ABCB', 'ABCL', 'ABEO', 'ABG', 'ABL', 'ABLLW', 'ABLV', 'ABLVW', 'ABM', 'ABNB', 'ABOS', 'ABR', 'ABSI', 'ABT', 'ABTS', 'ABUS', 'ABVC', 'ABVE', 'ABVEW', 'AC', 'ACA', 'ACAD', 'ACB', 'ACCD', 'ACCO', 'ACDC', 'ACEL', 'ACET', 'ACGL', 'ACHC', 'ACHR', 'ACHV', 'ACI', 'ACIC', 'ACIU', 'ACIW', 'ACLS', 'ACLX', 'ACM', 'ACMR', 'ACN', 'ACNB', 'ACNT', 'ACON', 'ACONW', 'ACR', 'ACRE', 'ACRS', 'ACRV', 'ACT', 'ACTG', 'ACTU', 'ACU', 'ACVA', 'ACXP', 'ADBE', 'ADC', 'ADCT', 'ADD', 'ADEA', 'ADGM', 'ADI', 'ADIL', 'ADM', 'ADMA', 'ADN', 'ADNT', 'ADNWW', 'ADP', 'ADPT', 'ADSE', 'ADSEW', 'ADSK', 'ADT', 'ADTN', 'ADTX', 'ADUS', 'ADV', 'ADVM', 'ADVWW', 'AE', 'AEE', 'AEG', 'AEHL', 'AEHR', 'AEI', 'AEIS', 'AEM', 'AEMD', 'AENT', 'AENTW', 'AEO', 'AEON', 'AEP', 'AER', 'AERT', 'AES', 'AESI', 'AEVA', 'AEYE', 'AFBI', 'AFCG', 'AFG', 'AFL', 'AFMD', 'AFRI', 'AFRIW', 'AFRM', 'AFYA', 'AG', 'AGAE', 'AGCO', 'AGEN', 'AGFY', 'AGI', 'AGIO', 'AGL', 'AGM', 'AGMH', 'AGNC', 'AGO', 'AGR', 'AGRI', 'AGRO', 'AGS', 'AGX', 'AGYS', 'AHCO', 'AHG', 'AHH', 'AHR', 'AHT', 'AI', 'AIEV', 'AIFF', 'AIG', 'AIHS', 'AILE', 'AILEW', 'AIM', 'AIMD', 'AIMDW', 'AIN', 'AIOT', 'AIP', 'AIR', 'AIRE', 'AIRG', 'AIRI', 'AIRJ', 'AIRJW', 'AIRS', 'AIRT', 'AISP', 'AISPW', 'AIT', 'AIV', 'AIZ', 'AJG', 'AJX', 'AKA', 'AKAM', 'AKAN', 'AKBA', 'AKR', 'AKRO', 'AKTS', 'AKTX', 'AKYA', 'AL', 'ALAB', 'ALB', 'ALBT', 'ALC', 'ALCE', 'ALCO', 'ALDX', 'ALE', 'ALEC', 'ALEX', 'ALG', 'ALGM', 'ALGN', 'ALGS', 'ALGT', 'ALHC', 'ALIT', 'ALK', 'ALKS', 'ALKT', 'ALL', 'ALLE', 'ALLK', 'ALLO', 'ALLR', 'ALLT', 'ALLY', 'ALMS', 'ALNT', 'ALNY', 'ALOT', 'ALRM', 'ALRN', 'ALRS', 'ALSN', 'ALT', 'ALTG', 'ALTI', 'ALTM', 'ALTO', 'ALTR', 'ALTS', 'ALUR', 'ALV', 'ALVO', 'ALVOW', 'ALVR', 'ALX', 'ALXO', 'ALZN', 'AM', 'AMAL', 'AMAT', 'AMBA', 'AMBC', 'AMBI', 'AMBP', 'AMC', 'AMCR', 'AMCX', 'AMD', 'AME', 'AMED', 'AMG', 'AMGN', 'AMH', 'AMIX', 'AMKR', 'AMLI', 'AMLX', 'AMN', 'AMP', 'AMPG', 'AMPGW', 'AMPH', 'AMPL', 'AMPS', 'AMPX', 'AMPY', 'AMR', 'AMRC', 'AMRK', 'AMRN', 'AMRX', 'AMS', 'AMSC', 'AMSF', 'AMST', 'AMT', 'AMTB', 'AMTM', 'AMTX', 'AMWD', 'AMWL', 'AMZN', 'AN', 'ANAB', 'ANDE', 'ANEB', 'ANET', 'ANF', 'ANGH', 'ANGHW', 'ANGI', 'ANGO', 'ANIK', 'ANIP', 'ANIX', 'ANNX', 'ANRO', 'ANSS', 'ANTX', 'ANVS', 'ANY', 'AOMR', 'AON', 'AORT', 'AOS', 'AOSL', 'AOUT', 'AP', 'APA', 'APAM', 'APCX', 'APCXW', 'APD', 'APDN', 'APEI', 'APG', 'APGE', 'APH', 'APLD', 'APLE', 'APLM', 'APLS', 'APLT', 'APM', 'APO', 'APOG', 'APP', 'APPF', 'APPN', 'APPS', 'APRE', 'APT', 'APTO', 'APTV', 'APVO', 'APWC', 'APYX', 'AQB', 'AQMS', 'AQN', 'AQST', 'AR', 'ARAY', 'ARBB', 'ARBE', 'ARBEW', 'ARC', 'ARCB', 'ARCC', 'ARCH', 'ARCO', 'ARCT', 'ARDT', 'ARDX', 'ARE', 'AREB', 'AREBW', 'AREC', 'AREN', 'ARES', 'ARHS', 'ARI', 'ARIS', 'ARKO', 'ARKOW', 'ARKR', 'ARL', 'ARLO', 'ARLP', 'ARMK', 'ARMN', 'ARMP', 'AROC', 'AROW', 'ARQ', 'ARQQ', 'ARQQW', 'ARQT', 'ARR', 'ARRY', 'ARTL', 'ARTNA', 'ARTV', 'ARTW', 'ARVN', 'ARW', 'ARWR', 'AS', 'ASA', 'ASAI', 'ASAN', 'ASB', 'ASC', 'ASGN', 'ASH', 'ASIX', 'ASLE', 'ASM', 'ASMB', 'ASML', 'ASNS', 'ASO', 'ASPI', 'ASPN', 'ASPS', 'ASR', 'ASRT', 'ASRV', 'ASST', 'ASTC', 'ASTE', 'ASTH', 'ASTI', 'ASTL', 'ASTLW', 'ASTS', 'ASUR', 'ASYS', 'ATAI', 'ATCH', 'ATEC', 'ATEN', 'ATER', 'ATEX', 'ATGE', 'ATGL', 'ATHA', 'ATI', 'ATIF', 'ATIP', 'ATKR', 'ATLC', 'ATLO', 'ATLX', 'ATMU', 'ATNF', 'ATNFW', 'ATNI', 'ATNM', 'ATO', 'ATOM', 'ATOS', 'ATPC', 'ATR', 'ATRA', 'ATRC', 'ATRO', 'ATS', 'ATSG', 'ATUS', 'ATXG', 'ATXI', 'ATXS', 'ATYR', 'AU', 'AUB', 'AUBN', 'AUDC', 'AUID', 'AUMN', 'AUNA', 'AUPH', 'AUR', 'AURA', 'AUROW', 'AUST', 'AUUD', 'AUUDW', 'AVA', 'AVAH', 'AVAL', 'AVAV', 'AVB', 'AVBP', 'AVD', 'AVDL', 'AVDX', 'AVGO', 'AVGR', 'AVIR', 'AVNS', 'AVNT', 'AVNW', 'AVO', 'AVPT', 'AVPTW', 'AVT', 'AVTE', 'AVTR', 'AVTX', 'AVXL', 'AVY', 'AWH', 'AWI', 'AWK', 'AWR', 'AWRE', 'AWX', 'AX', 'AXDX', 'AXGN', 'AXIL', 'AXL', 'AXNX', 'AXON', 'AXP', 'AXR', 'AXS', 'AXSM', 'AXTA', 'AXTI', 'AY', 'AYI', 'AYRO', 'AYTU', 'AZ', 'AZEK', 'AZI', 'AZO', 'AZPN', 'AZTA', ...

# %%
from yahooquery import Ticker
import pandas as pd



# 가치주 선정 기준
max_per = 15       # PER이 15 이하인 주식
max_pbr = 1.5      # PBR이 1.5 이하인 주식
min_dividend = 0.02 # 배당 수익률이 2% 이상인 주식

# 결과 저장할 리스트
value_stocks = []

# 티커별로 가치주 지표 확인
for ticker in ticker_list:
    try:
        # 데이터 가져오기
        stock = Ticker(ticker)
        
        # 과거 재무 데이터 불러오기
        valuation = stock.all_financial_data(frequency='a')
        valuation.reset_index(inplace=True)
        
        # 2015년 1월 1일 이전 데이터만 사용
        valuation_2015 = valuation[(valuation.index.get_level_values('asOfDate') < '2015-01-01') & (valuation.index.get_level_values('symbol') == ticker)]
        
        # 최신 데이터만 추출
        if not valuation_2015.empty:
            recent_data = valuation_2015.iloc[-1]
            
            # 지표 추출
            per = recent_data.get('trailingPE', None)        # PER
            pbr = recent_data.get('priceToBook', None)       # PBR
            dividend_yield = recent_data.get('dividendYield', 0)  # 배당 수익률 (퍼센트)
            
            # 가치주 선정 조건 확인
            if per and per <= max_per and pbr and pbr <= max_pbr and dividend_yield >= min_dividend:
                value_stocks.append({
                    'ticker': ticker,
                    'PER': per,
                    'PBR': pbr,
                    'dividend_yield': dividend_yield
                })
    
    except Exception as e:
        print(f"Error retrieving data for {ticker}: {e}")

# 결과 출력
value_stocks_df = pd.DataFrame(value_stocks)
print("2015년 1월 1일 기준으로 선정된 가치주 리스트:")
print(value_stocks_df)
# Out:
# Error retrieving data for A: 'Requested level (asOfDate) does not match index name (None)'
# Error retrieving data for AA: 'Requested level (asOfDate) does not match index name (None)'
# Error retrieving data for AADI: 'Requested level (asOfDate) does not match index name (None)'
# Error retrieving data for AAL: 'Requested level (asOfDate) does not match index name (None)'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 18
#      15 for ticker in ticker_list:
#      16     try:
#      17         # 데이터 가져오기
# ---> 18         stock = Ticker(ticker)
#      20         # 과거 재무 데이터 불러오기
#      21         valuation = stock.all_financial_data(frequency='a')
#
# File c:\Users\kjh\anaconda3\lib\site-packages\yahooquery\ticker.py:93, in Ticker.__init__(self, symbols, **kwargs)
#      92 def __init__(self, symbols, **kwargs):
# ---> 93     super(Ticker, self).__init__(**kwargs)
#      94     self.symbols = symbols
#      95     self.invalid_symbols = None
#
# File c:\Users\kjh\anaconda3\lib\site-packages\yahooquery\base.py:950, in _YahooFinance.__init__(self, **kwargs)
#     948     self.login()
#     949 else:
# --> 950     self.session = setup_session(self.session, self._setup_url)
#     951 self.crumb = get_crumb(self.session)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\yahooquery\utils\__init__.py:1373, in setup_session(session, url)
#    1371 url = url or DEFAULT_SESSION_URL
#    1372 try:
# -> 1373     response = session.get(url, allow_redirects=True)
#    1374 except SSLError:
#    1375     counter = 0
#
# File c:\Users\kjh\anaconda3\lib\site-packages\requests\sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\kjh\anaconda3\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\kjh\anaconda3\lib\site-packages\yahooquery\utils\__init__.py:1342, in TimeoutHTTPAdapter.send(self, request, **kwargs)
#    1340 if timeout is None:
#    1341     kwargs["timeout"] = self.timeout
# -> 1342 return super(TimeoutHTTPAdapter, self).send(request, **kwargs)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\urllib3\connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File c:\Users\kjh\anaconda3\lib\site-packages\urllib3\connectionpool.py:404, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     402 # Trigger any extra validation we need to do.
#     403 try:
# --> 404     self._validate_conn(conn)
#     405 except (SocketTimeout, BaseSSLError) as e:
#     406     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     407     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\urllib3\connectionpool.py:1058, in HTTPSConnectionPool._validate_conn(self, conn)
#    1056 # Force connect early to allow us to validate the connection.
#    1057 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1058     conn.connect()
#    1060 if not conn.is_verified:
#    1061     warnings.warn(
#    1062         (
#    1063             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1068         InsecureRequestWarning,
#    1069     )
#
# File c:\Users\kjh\anaconda3\lib\site-packages\urllib3\connection.py:419, in HTTPSConnection.connect(self)
#     410 if (
#     411     not self.ca_certs
#     412     and not self.ca_cert_dir
#    (...)
#     415     and hasattr(context, "load_default_certs")
#     416 ):
#     417     context.load_default_certs()
# --> 419 self.sock = ssl_wrap_socket(
#     420     sock=conn,
#     421     keyfile=self.key_file,
#     422     certfile=self.cert_file,
#     423     key_password=self.key_password,
#     424     ca_certs=self.ca_certs,
#     425     ca_cert_dir=self.ca_cert_dir,
#     426     ca_cert_data=self.ca_cert_data,
#     427     server_hostname=server_hostname,
#     428     ssl_context=context,
#     429     tls_in_tls=tls_in_tls,
#     430 )
#     432 # If we're using all defaults and the connection
#     433 # is TLSv1 or TLSv1.1 we throw a DeprecationWarning
#     434 # for the host.
#     435 if (
#     436     default_ssl_context
#     437     and self.ssl_version is None
#     438     and hasattr(self.sock, "version")
#     439     and self.sock.version() in {"TLSv1", "TLSv1.1"}
#     440 ):
#
# File c:\Users\kjh\anaconda3\lib\site-packages\urllib3\util\ssl_.py:449, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     437     warnings.warn(
#     438         "An HTTPS request has been made, but the SNI (Server Name "
#     439         "Indication) extension to TLS is not available on this platform. "
#    (...)
#     445         SNIMissingWarning,
#     446     )
#     448 if send_sni:
# --> 449     ssl_sock = _ssl_wrap_socket_impl(
#     450         sock, context, tls_in_tls, server_hostname=server_hostname
#     451     )
#     452 else:
#     453     ssl_sock = _ssl_wrap_socket_impl(sock, context, tls_in_tls)
#
# File c:\Users\kjh\anaconda3\lib\site-packages\urllib3\util\ssl_.py:493, in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     490     return SSLTransport(sock, ssl_context, server_hostname)
#     492 if server_hostname:
# --> 493     return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494 else:
#     495     return ssl_context.wrap_socket(sock)
#
# File c:\Users\kjh\anaconda3\lib\ssl.py:501, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     495 def wrap_socket(self, sock, server_side=False,
#     496                 do_handshake_on_connect=True,
#     497                 suppress_ragged_eofs=True,
#     498                 server_hostname=None, session=None):
#     499     # SSLSocket class handles server_hostname encoding before it calls
#     500     # ctx._wrap_socket()
# --> 501     return self.sslsocket_class._create(
#     502         sock=sock,
#     503         server_side=server_side,
#     504         do_handshake_on_connect=do_handshake_on_connect,
#     505         suppress_ragged_eofs=suppress_ragged_eofs,
#     506         server_hostname=server_hostname,
#     507         context=self,
#     508         session=session
#     509     )
#
# File c:\Users\kjh\anaconda3\lib\ssl.py:1074, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1071         if timeout == 0.0:
#    1072             # non-blocking
#    1073             raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1074         self.do_handshake()
#    1075 except (OSError, ValueError):
#    1076     self.close()
#
# File c:\Users\kjh\anaconda3\lib\ssl.py:1343, in SSLSocket.do_handshake(self, block)
#    1341     if timeout == 0.0 and block:
#    1342         self.settimeout(None)
# -> 1343     self._sslobj.do_handshake()
#    1344 finally:
#    1345     self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
ticker_list
# Out:
# ['A',
#  'AA',
#  'AADI',
#  'AAL',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAP',
#  'AAPL',
#  'AAT',
#  'AB',
#  'ABAT',
#  'ABBV',
#  'ABCB',
#  'ABCL',
#  'ABEO',
#  'ABG',
#  'ABL',
#  'ABLLW',
#  'ABLV',
#  'ABLVW',
#  'ABM',
#  'ABNB',
#  'ABOS',
#  'ABR',
#  'ABSI',
#  'ABT',
#  'ABTS',
#  'ABUS',
#  'ABVC',
#  'ABVE',
#  'ABVEW',
#  'AC',
#  'ACA',
#  'ACAD',
#  'ACB',
#  'ACCD',
#  'ACCO',
#  'ACDC',
#  'ACEL',
#  'ACET',
#  'ACGL',
#  'ACHC',
#  'ACHR',
#  'ACHV',
#  'ACI',
#  'ACIC',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACM',
#  'ACMR',
#  'ACN',
#  'ACNB',
#  'ACNT',
#  'ACON',
#  'ACONW',
#  'ACR',
#  'ACRE',
#  'ACRS',
#  'ACRV',
#  'ACT',
#  'ACTG',
#  'ACTU',
#  'ACU',
#  'ACVA',
#  'ACXP',
#  'ADBE',
#  'ADC',
#  'ADCT',
#  'ADD',
#  'ADEA',
#  'ADGM',
#  'ADI',
#  'ADIL',
#  'ADM',
#  'ADMA',
#  'ADN',
#  'ADNT',
#  'ADNWW',
#  'ADP',
#  'ADPT',
#  'ADSE',
#  'ADSEW',
#  'ADSK',
#  'ADT',
#  'ADTN',
#  'ADTX',
#  'ADUS',
#  'ADV',
#  'ADVM',
#  'ADVWW',
#  'AE',
#  'AEE',
#  'AEG',
#  'AEHL',
#  'AEHR',
#  'AEI',
#  'AEIS',
#  'AEM',
#  'AEMD',
#  'AENT',
#  'AENTW',
#  'AEO',
#  'AEON',
#  'AEP',
#  'AER',
#  'AERT',
#  'AES',
#  'AESI',
#  'AEVA',
#  'AEYE',
#  'AFBI',
#  'AFCG',
#  'AFG',
#  'AFL',
#  'AFMD',
#  'AFRI',
#  'AFRIW',
#  'AFRM',
#  'AFYA',
#  'AG',
#  'AGAE',
#  'AGCO',
#  'AGEN',
#  'AGFY',
#  'AGI',
#  'AGIO',
#  'AGL',
#  'AGM',
#  'AGMH',
#  'AGNC',
#  'AGO',
#  'AGR',
#  'AGRI',
#  'AGRO',
#  'AGS',
#  'AGX',
#  'AGYS',
#  'AHCO',
#  'AHG',
#  'AHH',
#  'AHR',
#  'AHT',
#  'AI',
#  'AIEV',
#  'AIFF',
#  'AIG',
#  'AIHS',
#  'AILE',
#  'AILEW',
#  'AIM',
#  'AIMD',
#  'AIMDW',
#  'AIN',
#  'AIOT',
#  'AIP',
#  'AIR',
#  'AIRE',
#  'AIRG',
#  'AIRI',
#  'AIRJ',
#  'AIRJW',
#  'AIRS',
#  'AIRT',
#  'AISP',
#  'AISPW',
#  'AIT',
#  'AIV',
#  'AIZ',
#  'AJG',
#  'AJX',
#  'AKA',
#  'AKAM',
#  'AKAN',
#  'AKBA',
#  'AKR',
#  'AKRO',
#  'AKTS',
#  'AKTX',
#  'AKYA',
#  'AL',
#  'ALAB',
#  'ALB',
#  'ALBT',
#  'ALC',
#  'ALCE',
#  'ALCO',
#  'ALDX',
#  'ALE',
#  'ALEC',
#  'ALEX',
#  'ALG',
#  'ALGM',
#  'ALGN',
#  'ALGS',
#  'ALGT',
#  'ALHC',
#  'ALIT',
#  'ALK',
#  'ALKS',
#  'ALKT',
#  'ALL',
#  'ALLE',
#  'ALLK',
#  'ALLO',
#  'ALLR',
#  'ALLT',
#  'ALLY',
#  'ALMS',
#  'ALNT',
#  'ALNY',
#  'ALOT',
#  'ALRM',
#  'ALRN',
#  'ALRS',
#  'ALSN',
#  'ALT',
#  'ALTG',
#  'ALTI',
#  'ALTM',
#  'ALTO',
#  'ALTR',
#  'ALTS',
#  'ALUR',
#  'ALV',
#  'ALVO',
#  'ALVOW',
#  'ALVR',
#  'ALX',
#  'ALXO',
#  'ALZN',
#  'AM',
#  'AMAL',
#  'AMAT',
#  'AMBA',
#  'AMBC',
#  'AMBI',
#  'AMBP',
#  'AMC',
#  'AMCR',
#  'AMCX',
#  'AMD',
#  'AME',
#  'AMED',
#  'AMG',
#  'AMGN',
#  'AMH',
#  'AMIX',
#  'AMKR',
#  'AMLI',
#  'AMLX',
#  'AMN',
#  'AMP',
#  'AMPG',
#  'AMPGW',
#  'AMPH',
#  'AMPL',
#  'AMPS',
#  'AMPX',
#  'AMPY',
#  'AMR',
#  'AMRC',
#  'AMRK',
#  'AMRN',
#  'AMRX',
#  'AMS',
#  'AMSC',
#  'AMSF',
#  'AMST',
#  'AMT',
#  'AMTB',
#  'AMTM',
#  'AMTX',
#  'AMWD',
#  'AMWL',
#  'AMZN',
#  'AN',
#  'ANAB',
#  'ANDE',
#  'ANEB',
#  'ANET',
#  'ANF',
#  'ANGH',
#  'ANGHW',
#  'ANGI',
#  'ANGO',
#  'ANIK',
#  'ANIP',
#  'ANIX',
#  'ANNX',
#  'ANRO',
#  'ANSS',
#  'ANTX',
#  'ANVS',
#  'ANY',
#  'AOMR',
#  'AON',
#  'AORT',
#  'AOS',
#  'AOSL',
#  'AOUT',
#  'AP',
#  'APA',
#  'APAM',
#  'APCX',
#  'APCXW',
#  'APD',
#  'APDN',
#  'APEI',
#  'APG',
#  'APGE',
#  'APH',
#  'APLD',
#  'APLE',
#  'APLM',
#  'APLS',
#  'APLT',
#  'APM',
#  'APO',
#  'APOG',
#  'APP',
#  'APPF',
#  'APPN',
#  'APPS',
#  'APRE',
#  'APT',
#  'APTO',
#  'APTV',
#  'APVO',
#  'APWC',
#  'APYX',
#  'AQB',
#  'AQMS',
#  'AQN',
#  'AQST',
#  'AR',
#  'ARAY',
#  'ARBB',
#  'ARBE',
#  'ARBEW',
#  'ARC',
#  'ARCB',
#  'ARCC',
#  'ARCH',
#  'ARCO',
#  'ARCT',
#  'ARDT',
#  'ARDX',
#  'ARE',
#  'AREB',
#  'AREBW',
#  'AREC',
#  'AREN',
#  'ARES',
#  'ARHS',
#  'ARI',
#  'ARIS',
#  'ARKO',
#  'ARKOW',
#  'ARKR',
#  'ARL',
#  'ARLO',
#  'ARLP',
#  'ARMK',
#  'ARMN',
#  'ARMP',
#  'AROC',
#  'AROW',
#  'ARQ',
#  'ARQQ',
#  'ARQQW',
#  'ARQT',
#  'ARR',
#  'ARRY',
#  'ARTL',
#  'ARTNA',
#  'ARTV',
#  'ARTW',
#  'ARVN',
#  'ARW',
#  'ARWR',
#  'AS',
#  'ASA',
#  'ASAI',
#  'ASAN',
#  'ASB',
#  'ASC',
#  'ASGN',
#  'ASH',
#  'ASIX',
#  'ASLE',
#  'ASM',
#  'ASMB',
#  'ASML',
#  'ASNS',
#  'ASO',
#  'ASPI',
#  'ASPN',
#  'ASPS',
#  'ASR',
#  'ASRT',
#  'ASRV',
#  'ASST',
#  'ASTC',
#  'ASTE',
#  'ASTH',
#  'ASTI',
#  'ASTL',
#  'ASTLW',
#  'ASTS',
#  'ASUR',
#  'ASYS',
#  'ATAI',
#  'ATCH',
#  'ATEC',
#  'ATEN',
#  'ATER',
#  'ATEX',
#  'ATGE',
#  'ATGL',
#  'ATHA',
#  'ATI',
#  'ATIF',
#  'ATIP',
#  'ATKR',
#  'ATLC',
#  'ATLO',
#  'ATLX',
#  'ATMU',
#  'ATNF',
#  'ATNFW',
#  'ATNI',
#  'ATNM',
#  'ATO',
#  'ATOM',
#  'ATOS',
#  'ATPC',
#  'ATR',
#  'ATRA',
#  'ATRC',
#  'ATRO',
#  'ATS',
#  'ATSG',
#  'ATUS',
#  'ATXG',
#  'ATXI',
#  'ATXS',
#  'ATYR',
#  'AU',
#  'AUB',
#  'AUBN',
#  'AUDC',
#  'AUID',
#  'AUMN',
#  'AUNA',
#  'AUPH',
#  'AUR',
#  'AURA',
#  'AUROW',
#  'AUST',
#  'AUUD',
#  'AUUDW',
#  'AVA',
#  'AVAH',
#  'AVAL',
#  'AVAV',
#  'AVB',
#  'AVBP',
#  'AVD',
#  'AVDL',
#  'AVDX',
#  'AVGO',
#  'AVGR',
#  'AVIR',
#  'AVNS',
#  'AVNT',
#  'AVNW',
#  'AVO',
#  'AVPT',
#  'AVPTW',
#  'AVT',
#  'AVTE',
#  'AVTR',
#  'AVTX',
#  'AVXL',
#  'AVY',
#  'AWH',
#  'AWI',
#  'AWK',
#  'AWR',
#  'AWRE',
#  'AWX',
#  'AX',
#  'AXDX',
#  'AXGN',
#  'AXIL',
#  'AXL',
#  'AXNX',
#  'AXON',
#  'AXP',
#  'AXR',
#  'AXS',
#  'AXSM',
#  'AXTA',
#  'AXTI',
#  'AY',
#  'AYI',
#  'AYRO',
#  'AYTU',
#  'AZ',
#  'AZEK',
#  'AZI',
#  'AZO',
#  'AZPN',
#  'AZTA',
#  'AZTR',
#  'AZZ',
#  'B',
#  'BA',
#  'BAC',
#  'BACK',
#  'BAER',
#  'BAERW',
#  'BAFN',
#  'BAH',
#  'BAK',
#  'BALL',
#  'BALY',
#  'BAM',
#  'BANC',
#  'BAND',
#  'BANF',
#  'BANFP',
#  'BANL',
#  'BANR',
#  'BANX',
#  'BAOS',
#  'BAP',
#  'BARK',
#  'BASE',
#  'BATL',
#  'BATRA',
#  'BATRK',
#  'BAX',
#  'BB',
#  'BBAI',
#  'BBAR',
#  'BBCP',
#  'BBDC',
#  'BBGI',
#  'BBIO',
#  'BBLG',
#  'BBLGW',
#  'BBSI',
#  'BBU',
#  'BBUC',
#  'BBVA',
#  'BBW',
#  'BBWI',
#  'BBY',
#  'BC',
#  'BCAB',
#  'BCAL',
#  'BCAN',
#  'BCAT',
#  'BCAX',
#  'BCBP',
#  'BCC',
#  'BCDA',
#  'BCE',
#  'BCG',
#  'BCGWW',
#  'BCH',
#  'BCLI',
#  'BCML',
#  'BCO',
#  'BCOV',
#  'BCOW',
#  'BCPC',
#  'BCRX',
#  'BCS',
#  'BCSF',
#  'BCTX',
#  'BCTXW',
#  'BCX',
#  'BDC',
#  'BDJ',
#  'BDL',
#  'BDMD',
#  'BDMDW',
#  'BDN',
#  'BDSX',
#  'BDTX',
#  'BDX',
#  'BE',
#  'BEAM',
#  'BEAT',
#  'BEATW',
#  'BECN',
#  'BEEM',
#  'BELFA',
#  'BELFB',
#  'BEN',
#  'BENF',
#  'BENFW',
#  'BEP',
#  'BEPC',
#  'BERY',
#  'BETR',
#  'BETRW',
#  'BFAM',
#  'BFC',
#  'BFH',
#  'BFIN',
#  'BFLY',
#  'BFRG',
#  'BFRGW',
#  'BFRI',
#  'BFRIW',
#  'BFS',
#  'BFST',
#  'BG',
#  'BGC',
#  'BGFV',
#  'BGI',
#  'BGLC',
#  'BGM',
#  'BGR',
#  'BGS',
#  'BGSF',
#  'BH',
#  'BHAT',
#  'BHB',
#  'BHC',
#  'BHE',
#  'BHF',
#  'BHIL',
#  'BHLB',
#  'BHM',
#  'BHR',
#  'BHRB',
#  'BHVN',
#  'BIAF',
#  'BIAFW',
#  'BIDU',
#  'BIGC',
#  'BIGZ',
#  'BIIB',
#  'BILL',
#  'BIO',
#  'BIOA',
#  'BIOR',
#  'BIOX',
#  'BIP',
#  'BIPC',
#  'BIRD',
#  'BIRK',
#  'BITF',
#  'BIVI',
#  'BJ',
#  'BJDX',
#  'BJRI',
#  'BK',
#  'BKD',
#  'BKE',
#  'BKH',
#  'BKKT',
#  'BKNG',
#  'BKR',
#  'BKSY',
#  'BKT',
#  'BKTI',
#  'BKU',
#  'BKV',
#  'BKYI',
#  'BL',
#  'BLBD',
#  'BLBX',
#  'BLCO',
#  'BLD',
#  'BLDE',
#  'BLDEW',
#  'BLDP',
#  'BLDR',
#  'BLFS',
#  'BLFY',
#  'BLIN',
#  'BLK',
#  'BLKB',
#  'BLMN',
#  'BLMZ',
#  'BLND',
#  'BLNK',
#  'BLUE',
#  'BLW',
#  'BLX',
#  'BLZE',
#  'BMA',
#  'BMBL',
#  'BME',
#  'BMEA',
#  'BMEZ',
#  'BMI',
#  'BMO',
#  'BMR',
#  'BMRA',
#  'BMRC',
#  'BMRN',
#  'BMTX',
#  'BMY',
#  'BN',
#  'BNAI',
#  'BNAIW',
#  'BNED',
#  'BNGO',
#  'BNL',
#  'BNOX',
#  'BNRG',
#  'BNS',
#  'BNT',
#  'BNTC',
#  'BNZI',
#  'BNZIW',
#  'BOC',
#  'BODI',
#  'BOF',
#  'BOH',
#  'BOKF',
#  'BOLD',
#  'BOLT',
#  'BON',
#  'BOOM',
#  'BOOT',
#  'BORR',
#  'BOSC',
#  'BOTJ',
#  'BOW',
#  'BOWL',
#  'BOX',
#  'BOXL',
#  'BP',
#  'BPMC',
#  'BPOP',
#  'BPRN',
#  'BPT',
#  'BPTH',
#  'BR',
#  'BRAG',
#  'BRBR',
#  'BRBS',
#  'BRC',
#  'BRCC',
#  'BRDG',
#  'BREA',
#  'BRFH',
#  'BRFS',
#  'BRID',
#  'BRK/A',
#  'BRKL',
#  'BRKR',
#  'BRLS',
#  'BRLSW',
#  'BRLT',
#  'BRN',
#  'BRO',
#  'BROG',
#  'BROGW',
#  'BROS',
#  'BRSP',
#  'BRT',
#  'BRTX',
#  'BRX',
#  'BRY',
#  'BRZE',
#  'BSAC',
#  'BSBK',
#  'BSET',
#  'BSFC',
#  'BSIG',
#  'BSLK',
#  'BSLKW',
#  'BSM',
#  'BSRR',
#  'BST',
#  'BSTZ',
#  'BSVN',
#  'BSX',
#  'BSY',
#  'BTAI',
#  'BTBD',
#  'BTBDW',
#  'BTBT',
#  'BTCM',
#  'BTCS',
#  'BTCT',
#  'BTCTW',
#  'BTDR',
#  'BTE',
#  'BTG',
#  'BTI',
#  'BTM',
#  'BTMD',
#  'BTMWW',
#  'BTOC',
#  'BTOG',
#  'BTSG',
#  'BTSGU',
#  'BTTR',
#  'BTU',
#  'BTZ',
#  'BUD',
#  'BUR',
#  'BURL',
#  'BURU',
#  'BUSE',
#  'BV',
#  'BVFL',
#  'BVN',
#  'BVS',
#  'BW',
#  'BWA',
#  'BWB',
#  'BWEN',
#  'BWFG',
#  'BWIN',
#  'BWMN',
#  'BWMX',
#  'BWXT',
#  'BX',
#  'BXC',
#  'BXMT',
#  'BXP',
#  'BY',
#  'BYD',
#  'BYFC',
#  'BYND',
#  'BYON',
#  'BYRN',
#  'BYSI',
#  'BYU',
#  'BZ',
#  'BZFD',
#  'BZFDW',
#  'BZH',
#  'C',
#  'CAAP',
#  'CAAS',
#  'CABA',
#  'CABO',
#  'CAC',
#  'CACC',
#  'CACI',
#  'CADE',
#  'CADL',
#  'CAE',
#  'CAG',
#  'CAH',
#  'CAKE',
#  'CAL',
#  'CALC',
#  'CALM',
#  'CALX',
#  'CAMT',
#  'CANF',
#  'CAPL',
#  'CAPR',
#  'CAPT',
#  'CAR',
#  'CARA',
#  'CARE',
#  'CARG',
#  'CARM',
#  'CARR',
#  'CARS',
#  'CART',
#  'CARV',
#  'CASH',
#  'CASI',
#  'CASS',
#  'CASY',
#  'CAT',
#  'CATO',
#  'CATX',
#  'CATY',
#  'CAVA',
#  'CB',
#  'CBAN',
#  'CBAT',
#  'CBFV',
#  'CBL',
#  'CBLL',
#  'CBNA',
#  'CBNK',
#  'CBOE',
#  'CBRE',
#  'CBRL',
#  'CBSH',
#  'CBT',
#  'CBU',
#  'CBUS',
#  'CBZ',
#  'CC',
#  'CCAP',
#  'CCB',
#  'CCBG',
#  'CCCC',
#  'CCCS',
#  'CCEC',
#  'CCEL',
#  'CCEP',
#  'CCG',
#  'CCI',
#  'CCJ',
#  'CCK',
#  'CCL',
#  'CCLD',
#  'CCNE',
#  'CCO',
#  'CCOI',
#  'CCRD',
#  'CCRN',
#  'CCS',
#  'CCSI',
#  'CCTG',
#  'CCU',
#  'CCZ',
#  'CDE',
#  'CDIO',
#  'CDIOW',
#  'CDLX',
#  'CDMO',
#  'CDNA',
#  'CDNS',
#  'CDP',
#  'CDRE',
#  'CDRO',
#  'CDROW',
#  'CDT',
#  'CDTG',
#  'CDTTW',
#  'CDTX',
#  'CDW',
#  'CDXC',
#  'CDXS',
#  'CDZI',
#  'CE',
#  'CEAD',
#  'CECO',
#  'CEG',
#  'CEIX',
#  'CELC',
#  'CELH',
#  'CELU',
#  'CELUW',
#  'CELZ',
#  'CENN',
#  'CENT',
#  'CENTA',
#  'CENX',
#  'CEP',
#  'CERO',
#  'CEROW',
#  'CERS',
#  'CERT',
#  'CET',
#  'CETX',
#  'CETY',
#  'CEV',
#  'CEVA',
#  'CF',
#  'CFB',
#  'CFBK',
#  'CFFI',
#  'CFFN',
#  'CFG',
#  'CFLT',
#  'CFR',
#  'CFSB',
#  'CG',
#  'CGA',
#  'CGAU',
#  'CGBD',
#  'CGBS',
#  'CGBSW',
#  'CGC',
#  'CGEM',
#  'CGEN',
#  'CGNT',
#  'CGNX',
#  'CGTX',
#  'CHCI',
#  'CHCO',
#  'CHCT',
#  'CHD',
#  'CHDN',
#  'CHE',
#  'CHEF',
#  'CHEK',
#  ...]
